# %% [markdown]
# <a href="https://colab.research.google.com/github/Josue-A84/IA/blob/main/NLP_Clase1_Semillero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1: Logistic Regression
# Welcome to week one of this specialization. You will learn about logistic regression. Concretely, you will be implementing logistic regression for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Learn how to extract features for logistic regression given some text
# * Implement logistic regression from scratch
# * Apply logistic regression on a natural language processing task
# * Test using your logistic regression
# * Perform error analysis
#
# ## Important Note on Submission to the AutoGrader
#
# Before submitting your assignment to the AutoGrader, please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.
#
# If you do any of the following, you will get something like, `Grader Error: Grader feedback not found` (or similarly unexpected) error upon submitting your assignment. Before asking for help/debugging the errors in your assignment, check for these first. If this is the case, and you don't remember the changes you have made, you can get a fresh copy of the assignment by following these [instructions](https://www.coursera.org/learn/classification-vector-spaces-in-nlp/supplement/YLuAg/h-ow-to-refresh-your-workspace).
#
# Lets get started!
#
# We will be using a data set of tweets. Hopefully you will get more than 99% accuracy.
# Run the cell below to load in the packages.

# %% [markdown]
# ## Table of Contents
#
# - [Import Functions and Data](#0)
# - [1 - Logistic Regression](#1)
#     - [1.1 - Sigmoid](#1-1)
#         - [Exercise 1 - sigmoid (UNQ_C1)](#ex-1)
#     - [1.2 - Cost function and Gradient](#1-2)
#         - [Exercise 2 - gradientDescent (UNQ_C2)](#ex-2)
# - [2 - Extracting the Features](#2)
#     - [Exercise 3 - extract_features (UNQ_C3)](#ex-3)
# - [3 - Training Your Model](#3)
# - [4 - Test your Logistic Regression](#4)
#     - [Exercise 4 - predict_tweet (UNQ_C4)](#ex-4)
#     - [4.1 - Check the Performance using the Test Set](#4-1)
#         - [Exercise 5 - test_logistic_regression (UNQ_C5)](#ex-5)
# - [5 - Error Analysis](#5)
# - [6 - Predict with your own Tweet](#6)

# %% [markdown]
# <a name='0'></a>
# ## Import Functions and Data

# %%
# run this cell to import nltk
import nltk
from os import getcwd


nltk.download('twitter_samples')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ### Imported Functions
#
# Download the data needed for this assignment. Check out the [documentation for the twitter_samples dataset](http://www.nltk.org/howto/twitter.html).
#
# * twitter_samples: if you're running this notebook on your local computer, you will need to download it using:
# ```Python
# nltk.download('twitter_samples')
# ```
#
# * stopwords: if you're running this notebook on your local computer, you will need to download it using:
# ```python
# nltk.download('stopwords')
# ```
#
# #### Import some helper functions that we provided in the utils.py file:
# * process_tweet: cleans the text, tokenizes it into separate words, removes stopwords, and converts words to stems.
# * build_freqs: this counts how often a word in the 'corpus' (the entire set of tweets) was associated with a positive label '1' or a negative label '0', then builds the 'freqs' dictionary, where each key is the (word,label) tuple, and the value is the count of its frequency within the corpus of tweets.

# %%
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
def process_tweet(tweet):
    import re
    import string
    from nltk.corpus import stopwords
    from nltk.stem import PorterStemmer

    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')

    # eliminar hipervínculos
    tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    # eliminar menciones y hashtags
    tweet = re.sub(r'@[A-Za-z0-9_]+', '', tweet)
    tweet = re.sub(r'#', '', tweet)
    # eliminar puntuación
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))

    # tokenización
    words = tweet.split()
    clean_words = []

    for word in words:
        word = word.lower()
        if word not in stopwords_english:
            stem_word = stemmer.stem(word)
            clean_words.append(stem_word)

    return clean_words


def build_freqs(tweets, ys):
    import numpy as np
    from collections import defaultdict
    freqs = defaultdict(int)
    for y, tweet in zip(ys, tweets):
      y = int(np.squeeze(y))
      for word in process_tweet(tweet):
            pair = (word, y)
            freqs[pair] += 1

    return freqs

# %%
import numpy as np
import pandas as pd
from nltk.corpus import twitter_samples

# %% [markdown]
# ### Prepare the Data
# * The `twitter_samples` contains subsets of five thousand positive_tweets, five thousand negative_tweets, and the full set of 10,000 tweets.
#     * If you used all three datasets, we would introduce duplicates of the positive tweets and negative tweets.
#     * You will select just the five thousand positive tweets and five thousand negative tweets.

# %%
# select the set of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %% [markdown]
# * Train test split: 20% will be in the test set, and 80% in the training set.

# %%
# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# %% [markdown]
# * Create the numpy array of positive labels and negative labels.

# %%
# combine positive and negative labels
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis=0)
test_y = np.append(np.ones((len(test_pos), 1)), np.zeros((len(test_neg), 1)), axis=0)

# %%
# Print the shape train and test sets
print("train_y.shape = " + str(train_y.shape))
print("test_y.shape = " + str(test_y.shape))
# Out:
# train_y.shape = (8000, 1)
# test_y.shape = (2000, 1)

# %% [markdown]
# * Create the frequency dictionary using the imported build_freqs function.
#     * We highly recommend that you open utils.py and read the build_freqs function to understand what it is doing.
#     * To view the file directory, go to the menu and click File->Open.
#
# ```Python
#     for y,tweet in zip(ys, tweets):
#         for word in process_tweet(tweet):
#             pair = (word, y)
#             if pair in freqs:
#                 freqs[pair] += 1
#             else:
#                 freqs[pair] = 1
# ```
# * Notice how the outer for loop goes through each tweet, and the inner for loop steps through each word in a tweet.
# * The 'freqs' dictionary is the frequency dictionary that's being built.
# * The key is the tuple (word, label), such as ("happy",1) or ("happy",0).  The value stored for each key is the count of how many times the word "happy" was associated with a positive label, or how many times "happy" was associated with a negative label.

# %%
# create frequency dictionary
freqs = build_freqs(train_x, train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'collections.defaultdict'>
# len(freqs) = 11431

# %% [markdown]
# #### Expected output
# ```
# type(freqs) = <class 'dict'>
# len(freqs) = 11436
# ```

# %% [markdown]
# ### Process Tweet
# The given function 'process_tweet' tokenizes the tweet into individual words, removes stop words and applies stemming.

# %%
# test the function below
print('This is an example of a positive tweet: \n', train_x[0])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[0]))
# Out:
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processed version of the tweet:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week']

# %% [markdown]
# #### Expected output
# ```
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processes version:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ```

# %% [markdown]
# <a name='1'></a>
# ## 1 - Logistic Regression
#
# <a name='1-1'></a>
# ### 1.1 - Sigmoid
# You will learn to use logistic regression for text classification.
# * The sigmoid function is defined as:
#
# $$ h(z) = \frac{1}{1+\exp^{-z}} \tag{1}$$
#
# It maps the input 'z' to a value that ranges between 0 and 1, and so it can be treated as a probability.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='./images/sigmoid_plot.jpg' alt="alternate text" width="width" height="height" style="width:300px;height:200px;" /> Figure 1 </div>

# %% [markdown]
# <a name='ex-1'></a>
# ### Exercise 1 -  sigmoid
# Implement the sigmoid function.
# * You will want this function to work if z is a scalar as well as if it is an array.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.exp.html" > numpy.exp </a> </li>
#
# </ul>
# </p>

# %%
# UNQ_C1 GRADED FUNCTION: sigmoid
def sigmoid(z):
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''


    # calculate the sigmoid of z
    h = 1 / ( 1+ np.exp(-z))

    ### END CODE HERE ###

    return h

# %%
# Testing your function
if (sigmoid(0) == 0.5):
    print('SUCCESS!')
else:
    print('Oops!')

if (sigmoid(4.92) == 0.9927537604041685):
    print('CORRECT!')
else:
    print('Oops again!')
# Out:
# SUCCESS!
# CORRECT!

# %% [markdown]
# #### Logistic Regression: Regression and a Sigmoid
#
# Logistic regression takes a regular linear regression, and applies a sigmoid to the output of the linear regression.
#
# Regression:
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# Note that the $\theta$ values are "weights". If you took the deep learning specialization, we referred to the weights with the 'w' vector.  In this course, we're using a different variable $\theta$ to refer to the weights.
#
# Logistic regression
# $$ h(z) = \frac{1}{1+\exp^{-z}}$$
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# We will refer to 'z' as the 'logits'.

# %% [markdown]
# <a name='1-2'></a>
# ### 1.2 - Cost function and Gradient
#
# The cost function used for logistic regression is the average of the log loss across all training examples:
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^m y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)}))\tag{5} $$
# * $m$ is the number of training examples
# * $y^{(i)}$ is the actual label of training example 'i'.
# * $h(z^{(i)})$ is the model's prediction for the training example 'i'.
#
# The loss function for a single training example is
# $$ Loss = -1 \times \left( y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) \right)$$
#
# * All the $h$ values are between 0 and 1, so the logs will be negative. That is the reason for the factor of -1 applied to the sum of the two loss terms.
# * Note that when the model predicts 1 ($h(z(\theta)) = 1$) and the label 'y' is also 1, the loss for that training example is 0.
# * Similarly, when the model predicts 0 ($h(z(\theta)) = 0$) and the actual label is also 0, the loss for that training example is 0.
# * However, when the model prediction is close to 1 ($h(z(\theta)) = 0.9999$) and the label is 0, the second term of the log loss becomes a large negative number, which is then multiplied by the overall factor of -1 to convert it to a positive loss value. $-1 \times (1 - 0) \times log(1 - 0.9999) \approx 9.2$ The closer the model prediction gets to 1, the larger the loss.

# %%
# verify that when the model predicts close to 1, but the actual label is 0, the loss is a large positive value
-1 * (1 - 0) * np.log(1 - 0.9999) # loss is about 9.2
# Out:
# np.float64(9.210340371976294)

# %% [markdown]
# * Likewise, if the model predicts close to 0 ($h(z) = 0.0001$) but the actual label is 1, the first term in the loss function becomes a large number: $-1 \times log(0.0001) \approx 9.2$.  The closer the prediction is to zero, the larger the loss.

# %%
# verify that when the model predicts close to 0 but the actual label is 1, the loss is a large positive value
-1 * np.log(0.0001) # loss is about 9.2
# Out:
# np.float64(9.210340371976182)

# %% [markdown]
# #### Update the weights
#
# To update your weight vector $\theta$, you will apply gradient descent to iteratively improve your model's predictions.
# The gradient of the cost function $J$ with respect to one of the weights $\theta_j$ is:
#
# $$\nabla_{\theta_j}J(\theta) = \frac{1}{m} \sum_{i=1}^m(h^{(i)}-y^{(i)})x^{(i)}_j \tag{5}$$
# * 'i' is the index across all 'm' training examples.
# * 'j' is the index of the weight $\theta_j$, so $x^{(i)}_j$ is the feature associated with weight $\theta_j$
#
# * To update the weight $\theta_j$, we adjust it by subtracting a fraction of the gradient determined by $\alpha$:
# $$\theta_j = \theta_j - \alpha \times \nabla_{\theta_j}J(\theta) $$
# * The learning rate $\alpha$ is a value that we choose to control how big a single update will be.

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - gradientDescent
# Implement gradient descent function.
# * The number of iterations 'num_iters" is the number of times that you'll use the entire training set.
# * For each iteration, you'll calculate the cost function using all training examples (there are 'm' training examples), and for all features.
# * Instead of updating a single weight $\theta_i$ at a time, we can update all the weights in the column vector:
# $$\mathbf{\theta} = \begin{pmatrix}
# \theta_0
# \\
# \theta_1
# \\
# \theta_2
# \\
# \vdots
# \\
# \theta_n
# \end{pmatrix}$$
# * $\mathbf{\theta}$ has dimensions (n+1, 1), where 'n' is the number of features, and there is one more element for the bias term $\theta_0$ (note that the corresponding feature value $\mathbf{x_0}$ is 1).
# * The 'logits', 'z', are calculated by multiplying the feature matrix 'x' with the weight vector 'theta'.  $z = \mathbf{x}\mathbf{\theta}$
#     * $\mathbf{x}$ has dimensions (m, n+1)
#     * $\mathbf{\theta}$: has dimensions (n+1, 1)
#     * $\mathbf{z}$: has dimensions (m, 1)
# * The prediction 'h', is calculated by applying the sigmoid to each element in 'z': $h(z) = sigmoid(z)$, and has dimensions (m,1).
# * The cost function $J$ is calculated by taking the dot product of the vectors 'y' and 'log(h)'.  Since both 'y' and 'h' are column vectors (m,1), transpose the vector to the left, so that matrix multiplication of a row vector with column vector performs the dot product.
# $$J = \frac{-1}{m} \times \left(\mathbf{y}^T \cdot log(\mathbf{h}) + \mathbf{(1-y)}^T \cdot log(\mathbf{1-h}) \right)$$
# * The update of theta is also vectorized.  Because the dimensions of $\mathbf{x}$ are (m, n+1), and both $\mathbf{h}$ and $\mathbf{y}$ are (m, 1), we need to transpose the $\mathbf{x}$ and place it on the left in order to perform matrix multiplication, which then yields the (n+1, 1) answer we need:
# $$\mathbf{\theta} = \mathbf{\theta} - \frac{\alpha}{m} \times \left( \mathbf{x}^T \cdot \left( \mathbf{h-y} \right) \right)$$

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>use numpy.dot for matrix multiplication.</li>
#     <li>To ensure that the fraction -1/m is a decimal value, cast either the numerator or denominator (or both), like `float(1)`, or write `1.` for the float version of 1. </li>
# </ul>
# </p>

# %%
# UNQ_C2 GRADED FUNCTION: gradientDescent
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE ###
    # get 'm', the number of rows in matrix x
    m = len(x)

    for i in range(0, num_iters):

        # get z, the dot product of x and theta
        z = np.dot(x, theta)

        # get the sigmoid of z
        h = sigmoid(z)

        # calculate the cost function
        J = -1/m * (np.dot(y.T, np.log(h)) + np.dot((1 - y).T, np.log(1 - h)))

        # update the weights theta
        theta = theta - (alpha/m) * np.dot(x.transpose(),(h-y))

    ### END CODE HERE ###
    J = float(J)
    return J, theta

# %%
# Check the function
# Construct a synthetic test case using numpy PRNG functions
np.random.seed(1)
# X input is 10 x 3 with ones for the bias terms
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis=1)
# Y Labels are 10 x 1
tmp_Y = (np.random.rand(10, 1) > 0.35).astype(float)

# Apply gradient descent
tmp_J, tmp_theta = gradientDescent(tmp_X, tmp_Y, np.zeros((3, 1)), 1e-8, 700)
print(f"The cost after training is {tmp_J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(tmp_theta)]}")
# Out:
# The cost after training is 0.67094970.
# The resulting vector of weights is [np.float64(4.1e-07), np.float64(0.00035658), np.float64(7.309e-05)]
# <ipython-input-22-963858b6b9cc>:34: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   J = float(J)

# %% [markdown]
# #### Expected output
# ```
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]
# ```

# %% [markdown]
# <a name='2'></a>
# ## 2 - Extracting the Features
#
# * Given a list of tweets, extract the features and store them in a matrix. You will extract two features.
#     * The first feature is the number of positive words in a tweet.
#     * The second feature is the number of negative words in a tweet.
# * Then train your logistic regression classifier on these features.
# * Test the classifier on a validation set.
#
# <a name='ex-3'></a>
# ### Exercise 3 - extract_features
# Implement the extract_features function.
# * This function takes in a single tweet.
# * Process the tweet using the imported `process_tweet` function and save the list of tweet words.
# * Loop through each word in the list of processed words
#     * For each word, check the 'freqs' dictionary for the count when that word has a positive '1' label. (Check for the key (word, 1.0)
#     * Do the same for the count for when the word is associated with the negative label '0'. (Check for the key (word, 0.0).)
#
# **Note:** In the implementation instructions provided above, the prediction of being positive or negative depends on feature vector which counts-in duplicate words - this is different from what you have seen in the lecture videos

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Make sure you handle cases when the (word, label) key is not found in the dictionary. </li>
#     <li> Search the web for hints about using the 'get' function of a Python dictionary.  Here is an <a href="https://www.programiz.com/python-programming/methods/dictionary/get" > example </a> </li>
# </ul>
# </p>

# %%
# UNQ_C3 GRADED FUNCTION: extract_features
def extract_features(tweet, freqs, process_tweet=process_tweet):
    '''
    Input:
        tweet: a string containing one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output:
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    word_l = process_tweet(tweet)

    # 3 elements for [bias, positive, negative] counts
    x = np.zeros(3)

    # bias term is set to 1
    x[0] = 1

    ### START CODE HERE ###

    # loop through each word in the list of words
    for word in word_l:

        # increment the word count for the positive label 1
        x[1] += freqs.get((word, 1.0),0)

        # increment the word count for the negative label 0
        x[2] += freqs.get((word, 0.0),0)

    ### END CODE HERE ###

    x = x[None, :]  # adding batch dimension for further processing
    assert(x.shape == (1, 3))
    return x

# %%
# Check your function
# test 1
# test on training data
tmp1 = extract_features(train_x[0], freqs)
print(tmp1)
# Out:
# [[  1. 171.  57.]]

# %% [markdown]
# #### Expected output
# ```
# [[1.000e+00 3.133e+03 6.100e+01]]
# ```

# %% [markdown]
# # test 2:
# # check for when the words are not in the freqs dictionary
# tmp2 = extract_features(tweet='This tweet has words like asdfghjkl and zxcvbnm.', freqs=freqs)
# print(tmp2)

# %% [markdown]
# #### Expected output
# ```
# [[1. 0. 0.]]
# ```

# %% [markdown]
# <a name='3'></a>
# ## 3 - Training Your Model
#
# To train the model:
# * Stack the features for all training examples into a matrix X.
# * Call `gradientDescent`, which you've implemented above.
#
# This section is given to you.  Please read it for understanding and run the cell.

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)

# training labels corresponding to X
Y = train_y

# Apply gradient descent
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# The cost after training is 0.69164919.
# The resulting vector of weights is [np.float64(-0.0), np.float64(4.054e-05), np.float64(-2.459e-05)]
# <ipython-input-26-963858b6b9cc>:34: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   J = float(J)

# %% [markdown]
# **Expected Output**:
#
# ```
# The cost after training is 0.22522315.
# The resulting vector of weights is [6e-08, 0.00053818, -0.0005583]
# ```

# %% [markdown]
# <a name='4'></a>
# ## 4 -  Test your Logistic Regression
#
# It is time for you to test your logistic regression function on some new input that your model has not seen before.
# <a name='ex-4'></a>
# ### Exercise 4 - predict_tweet
# Implement `predict_tweet`.
# Predict whether a tweet is positive or negative.
#
# * Given a tweet, process it, then extract the features.
# * Apply the model's learned weights on the features to get the logits.
# * Apply the sigmoid to the logits to get the prediction (a value between 0 and 1).
#
# $$y_{pred} = sigmoid(\mathbf{x} \cdot \theta)$$

# %%
# UNQ_C4 GRADED FUNCTION: predict_tweet
def predict_tweet(tweet, freqs, theta):
    '''
    Input:
        tweet: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output:
        y_pred: the probability of a tweet being positive or negative
    '''
    ### START CODE HERE ###

    # extract the features of the tweet and store it into x
    x = extract_features(tweet, freqs)

    # make the prediction using x and theta
    y_pred = sigmoid(np.dot(x, theta))

    ### END CODE HERE ###

    return y_pred

# %%
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
# Out:
# I am happy -> 0.501511
# I am bad -> 0.499847
# this movie should have been great. -> 0.501313
# great -> 0.501256
# great great -> 0.502511
# great great great -> 0.503767
# great great great great -> 0.505023
# <ipython-input-57-f9df493d3348>:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))

# %% [markdown]
# **Expected Output**:
# ```
# I am happy -> 0.519275
# I am bad -> 0.494347
# this movie should have been great. -> 0.515979
# great -> 0.516065
# great great -> 0.532096
# great great great -> 0.548062
# great great great great -> 0.563929
# ```

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'I think this course was excellent to learn a new area of technology :)'
predict_tweet(my_tweet, freqs, theta)
# Out:
# array([[0.50113939]])

# %% [markdown]
# <a name='4-1'></a>
# ### 4.1 -  Check the Performance using the Test Set
# After training your model using the training set above, check how your model might perform on real, unseen data, by testing it against the test set.
#
# <a name='ex-5'></a>
# ### Exercise 5 - test_logistic_regression
# Implement `test_logistic_regression`.
# * Given the test data and the weights of your trained model, calculate the accuracy of your logistic regression model.
# * Use your 'predict_tweet' function to make predictions on each tweet in the test set.
# * If the prediction is > 0.5, set the model's classification 'y_hat' to 1, otherwise set the model's classification 'y_hat' to 0.
# * A prediction is accurate when the y_hat equals the test_y.  Sum up all the instances when they are equal and divide by m.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use np.asarray() to convert a list to a numpy array</li>
#     <li>Use numpy.squeeze() to make an (m,1) dimensional array into an (m,) array </li>
# </ul>
# </p>

# %%
# UNQ_C5 GRADED FUNCTION: test_logistic_regression
def test_logistic_regression(test_x, test_y, freqs, theta, predict_tweet=predict_tweet):
    """
    Input:
        test_x: a list of tweets
        test_y: (m, 1) vector with the corresponding labels for the list of tweets
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output:
        accuracy: (# of tweets classified correctly) / (total # of tweets)
    """

    ### START CODE HERE ###

    # the list for storing predictions
    y_hat = []

    for tweet in test_x:
        # get the label prediction for the tweet
        y_pred = predict_tweet(tweet, freqs, theta)

        if y_pred > 0.5:
            # append 1.0 to the list
            y_hat.append(1.0)
        else:
            # append 0 to the list
            y_hat.append(0.0)

    # With the above implementation, y_hat is a list, but test_y is (m,1) array
    # convert both to one-dimensional arrays in order to compare them using the '==' operator
    accuracy = (y_hat == np.squeeze(test_y)).sum()/len(test_x)

    ### END CODE HERE ###

    return accuracy

# %%
tmp_accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmp_accuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.6660

# %% [markdown]
# #### Expected Output:
# ```0.9950```
# Pretty good!

# %% [markdown]
# <a name='5'></a>
# ## 5 -  Error Analysis
#
# In this part you will see some tweets that your model misclassified. Why do you think the misclassifications happened? Specifically what kind of tweets does your model misclassify?

# %%
# Some error analysis done for you
print('Label Predicted Tweet')
for x,y in zip(test_x,test_y):
    y_hat = predict_tweet(x, freqs, theta)

    if np.abs(y - (y_hat > 0.5)) > 0:
        print('THE TWEET IS:', x)
        print('THE PROCESSED TWEET IS:', process_tweet(x))
        print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Label Predicted Tweet
# THE TWEET IS: Bro:U wan cut hair anot,ur hair long Liao bo
# Me:since ord liao,take it easy lor treat as save $ leave it longer :)
# Bro:LOL Sibei xialan
# THE PROCESSED TWEET IS: ['brou', 'wan', 'cut', 'hair', 'anotur', 'hair', 'long', 'liao', 'bo', 'mesinc', 'ord', 'liaotak', 'easi', 'lor', 'treat', 'save', 'leav', 'longer', 'brolol', 'sibei', 'xialan']
# 1	0.49992832	b'brou wan cut hair anotur hair long liao bo mesinc ord liaotak easi lor treat save leav longer brolol sibei xialan'
# THE TWEET IS: @EllieVond @SkeletonSweets @Justin_Naito @justcallmerizzo No actually, you don't. Bye bye indeed. Go take your drama elsewhere. :)
# THE PROCESSED TWEET IS: ['actual', 'dont', 'bye', 'bye', 'inde', 'go', 'take', 'drama', 'elsewher']
# 1	0.49996290	b'actual dont bye bye inde go take drama elsewher'
# THE TWEET IS: @charlesjonesss F off :)
# THE PROCESSED TWEET IS: ['f']
# 1	0.49999385	b'f'
# THE TWEET IS: @V4Violetta *highfive* You are probably ahead of me there, since I am less artsy than verbal :D
# THE PROCESSED TWEET IS: ['highfiv', 'probabl', 'ahead', 'sinc', 'less', 'artsi', 'verbal']
# 1	0.49997672	b'highfiv probabl ahead sinc less artsi verbal'
# THE TWEET IS: @SeniorSpazz @TehSmileys I was bored so I did EVERYTHING :D
# THE PROCESSED TWEET IS: ['bore', 'everyth']
# 1	0.49998387	b'bore everyth'
# THE TWEET IS: I :)"@Kreizi_: Who wants a #FF S/O??"
# THE PROCESSED TWEET IS: ['want', 'ff']
# 1	0.49994275	b'want ff'
# THE TWEET IS: http://t.co/t2z9ax4qyd - hey, now! Come see us at the @NTCalkeAbbey Summer Fine Food Fair on Sunday, 11am-4pm in the Riding School :)
# THE PROCESSED TWEET IS: []
# 1	0.50000000	b''
# THE TWEET IS: you betcha :) dumb butt :)
# THE PROCESSED TWEET IS: ['betcha', 'dumb', 'butt']
# 1	0.50000000	b'betcha dumb butt'
# THE TWEET IS: kik : qualky808 #kik #kikmenow #milf #like4like #bored #summer #sexysaturday :) http://t.co/8R2Nrl31IC
# THE PROCESSED TWEET IS: ['kik', 'qualky808', 'kik', 'kikmenow', 'milf', 'like4lik', 'bore', 'summer', 'sexysaturday']
# 1	0.49962326	b'kik qualky808 kik kikmenow milf like4lik bore summer sexysaturday'
# THE TWEET IS: @Madison420Ivy  "We" ??? you wish :D:D:D:D:D:D:D kidding
# THE PROCESSED TWEET IS: ['wish', 'ddddddd', 'kid']
# 1	0.49993599	b'wish ddddddd kid'
# THE TWEET IS: @madpilot Before or after? :)
# THE PROCESSED TWEET IS: []
# 1	0.50000000	b''
# THE TWEET IS: @WaitlessCompany @Aledeleonmoreno glyon! :D
# THE PROCESSED TWEET IS: ['glyon']
# 1	0.50000000	b'glyon'
# THE TWEET IS: @FrolicHawaii this Saturday! :)
# THE PROCESSED TWEET IS: ['saturday']
# 1	0.49997906	b'saturday'
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots
# http://t.co/UGQzOx0huu
# THE PROCESSED TWEET IS: ['im', 'play', 'brain', 'dot', 'braindot']
# 1	0.49986471	b'im play brain dot braindot'
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/aOKldo3GMj http://t.co/xWCM9qyRG5
# THE PROCESSED TWEET IS: ['im', 'play', 'brain', 'dot', 'braindot']
# 1	0.49986471	b'im play brain dot braindot'
# THE TWEET IS: @MatjazSircelj ftw and all. :)
# THE PROCESSED TWEET IS: ['ftw']
# 1	0.49998770	b'ftw'
# THE TWEET IS: @Gotzefying Im trying to D/L MH3 english patch for the psp :D
# THE PROCESSED TWEET IS: ['im', 'tri', 'dl', 'mh3', 'english', 'patch', 'psp']
# 1	0.49947209	b'im tri dl mh3 english patch psp'
# THE TWEET IS: @Idxterr b3dk far7an ank mis15 :)???
# THE PROCESSED TWEET IS: ['b3dk', 'far7an', 'ank', 'mis15']
# 1	0.50000000	b'b3dk far7an ank mis15'
# THE TWEET IS: I just woke up and I feel incredibly sick idk if it's cause I drank Starbucks at 11 o'clock last night or if it's a reaction to my meds :)
# THE PROCESSED TWEET IS: ['woke', 'feel', 'incred', 'sick', 'idk', 'caus', 'drank', 'starbuck', '11', 'oclock', 'last', 'night', 'reaction', 'med']
# 1	0.49976342	b'woke feel incred sick idk caus drank starbuck 11 oclock last night reaction med'
# THE TWEET IS: @mussshiii @Takafofo so wat??:)
# THE PROCESSED TWEET IS: ['wat']
# 1	0.49999169	b'wat'
# THE TWEET IS: @_SW_E_ were you safe? :D
# THE PROCESSED TWEET IS: ['safe']
# 1	0.49999966	b'safe'
# THE TWEET IS: @SasaRichardson @Stefbystef_ @Frgt10_Anthem sombrero high?? OKAY I'M LOST NOW :)) http://t.co/2VDPgb5EpK
# THE PROCESSED TWEET IS: ['sombrero', 'high', 'okay', 'im', 'lost']
# 1	0.49954370	b'sombrero high okay im lost'
# THE TWEET IS: @MLGJordanD congrats on 100k Man. Can't wait till I can hit that milestone too :)
# THE PROCESSED TWEET IS: ['congrat', '100k', 'man', 'cant', 'wait', 'till', 'hit', 'mileston']
# 1	0.49999887	b'congrat 100k man cant wait till hit mileston'
# THE TWEET IS: @mariaburtea @5SOS_Nightly wow you really hate me :))))
# THE PROCESSED TWEET IS: ['wow', 'realli', 'hate']
# 1	0.49994725	b'wow realli hate'
# THE TWEET IS: Say something, I'm giving up on you :)
# And I'm sorry that I couldn't get to you :D
# THE PROCESSED TWEET IS: ['say', 'someth', 'im', 'give', 'im', 'sorri', 'couldnt', 'get']
# 1	0.49946076	b'say someth im give im sorri couldnt get'
# THE TWEET IS: @Anyi_anonadada @JosPastr @norcoreano a tope :))
# THE PROCESSED TWEET IS: ['tope']
# 1	0.50000000	b'tope'
# THE TWEET IS: @eonnicchi Why do you ask about it ? :&lt; ~ ended with him .. now i'm with him just friend :)
# THE PROCESSED TWEET IS: ['ask', 'lt', 'end', 'im', 'friend']
# 1	0.49979474	b'ask lt end im friend'
# THE TWEET IS: I will catch you if you fall. Fall ontrack :)
# THE PROCESSED TWEET IS: ['catch', 'fall', 'fall', 'ontrack']
# 1	0.49998968	b'catch fall fall ontrack'
# THE TWEET IS: @bekhyungh @cunyelo pinter :-)
# THE PROCESSED TWEET IS: ['pinter']
# 1	0.50000000	b'pinter'
# THE TWEET IS: @Vivienneclore That is so cute :-) 🐶
# THE PROCESSED TWEET IS: ['cute', '🐶']
# 1	0.49998536	b'cute '
# THE TWEET IS: @rachelburden Have a fabulous time. Will miss you. :) xx
# THE PROCESSED TWEET IS: ['fabul', 'time', 'miss', 'xx']
# 1	0.49919631	b'fabul time miss xx'
# THE TWEET IS: @sennicka don't over engineer it. :)
# THE PROCESSED TWEET IS: ['dont', 'engin']
# 1	0.49969585	b'dont engin'
# THE TWEET IS: and I have to be up for 7 :):):):)
# THE PROCESSED TWEET IS: ['7']
# 1	0.49999352	b'7'
# THE TWEET IS: if only you knew that the whole class was crying because of your hurtful words. :)
# THE PROCESSED TWEET IS: ['knew', 'whole', 'class', 'cri', 'hurt', 'word']
# 1	0.49975371	b'knew whole class cri hurt word'
# THE TWEET IS: Lunch at @imperiallamian :)
# THE PROCESSED TWEET IS: ['lunch']
# 1	0.49998122	b'lunch'
# THE TWEET IS: @_stevievie I'll be in Hawaii in December! We'll have a kick back again. Miss you too :)
# THE PROCESSED TWEET IS: ['ill', 'hawaii', 'decemb', 'well', 'kick', 'back', 'miss']
# 1	0.49980222	b'ill hawaii decemb well kick back miss'
# THE TWEET IS: hah....and a thousand more lies  :D https://t.co/QEil0C0auo
# THE PROCESSED TWEET IS: ['hahand', 'thousand', 'lie']
# 1	0.49998953	b'hahand thousand lie'
# THE TWEET IS: @wontanim yep we're all trash af   im from indonesia hbu? :-))
# THE PROCESSED TWEET IS: ['yep', 'trash', 'af', 'im', 'indonesia', 'hbu']
# 1	0.49954206	b'yep trash af im indonesia hbu'
# THE TWEET IS: Harry and niall and -94 (when harry was born) ik it's stupid and i wanna change it :D https://t.co/gHAt8ZDAfF
# THE PROCESSED TWEET IS: ['harri', 'niall', '94', 'harri', 'born', 'ik', 'stupid', 'wanna', 'chang']
# 1	0.49969920	b'harri niall 94 harri born ik stupid wanna chang'
# THE TWEET IS: @miabellasesso http://t.co/FtI5vLQJks @SBNation and a few select others.. will get to you :)
# THE PROCESSED TWEET IS: []
# 1	0.50000000	b''
# THE TWEET IS: @Uber_AHM and I have it :) http://t.co/sWLUm7Vtrz
# THE PROCESSED TWEET IS: []
# 1	0.50000000	b''
# THE TWEET IS: Goooood Mooorning :)
# I want to sleep again...
# THE PROCESSED TWEET IS: ['goooood', 'mooorn', 'want', 'sleep']
# 1	0.49948015	b'goooood mooorn want sleep'
# THE TWEET IS: You Lose :D
# THE PROCESSED TWEET IS: ['lose']
# 1	0.49997723	b'lose'
# THE TWEET IS: @fni Re-signed! :)
# THE PROCESSED TWEET IS: ['resign']
# 1	0.50000000	b'resign'
# THE TWEET IS: @hattersleyblue3 You too :-)
# THE PROCESSED TWEET IS: []
# 1	0.50000000	b''
# THE TWEET IS: @Ricky27_263 the remedies the media won't tell you about :-)
# THE PROCESSED TWEET IS: ['remedi', 'media', 'wont', 'tell']
# 1	0.49998551	b'remedi media wont tell'
# THE TWEET IS: @grafikmag @editionsdulivre I a kid inside!!! I want one!! :-)
# THE PROCESSED TWEET IS: ['kid', 'insid', 'want', 'one']
# 1	0.49980993	b'kid insid want one'
# THE TWEET IS: I AM SO SORRY FUCKING ERIC THINKS HES FUNNY :)
# THE PROCESSED TWEET IS: ['sorri', 'fuck', 'eric', 'think', 'he', 'funni']
# 1	0.49954927	b'sorri fuck eric think he funni'
# THE TWEET IS: There :) is :) a :) pimple :) on :) my :) forehead :) the :) size :) of :) a :) volcano :)
# THE PROCESSED TWEET IS: ['pimpl', 'forehead', 'size', 'volcano']
# 1	0.49996892	b'pimpl forehead size volcano'
# THE TWEET IS: @Memz_Dogi i'm joining right now :D
# THE PROCESSED TWEET IS: ['im', 'join', 'right']
# 1	0.49983430	b'im join right'
# THE TWEET IS: @dualityknight @bravefrontiergl lol sorry /-\ ultor is my very first hitter so...i favor him too much :))
# THE PROCESSED TWEET IS: ['lol', 'sorri', 'ultor', 'first', 'hitter', 'soi', 'favor', 'much']
# 1	0.49999720	b'lol sorri ultor first hitter soi favor much'
# THE TWEET IS: Only my bad would remind me to exercise at 1:12 in the am :-).
#  I miss her. She needs to come back. Now.
# THE PROCESSED TWEET IS: ['bad', 'would', 'remind', 'exercis', '112', 'miss', 'need', 'come', 'back']
# 1	0.49937198	b'bad would remind exercis 112 miss need come back'
# THE TWEET IS: Add me on KIK : ughtmed545 #kik #kikmeguys #kissme #nudes #likeforfollow #musicbiz #sexysasunday :) http://t.co/bgTjjz7fFN
# THE PROCESSED TWEET IS: ['add', 'kik', 'ughtmed545', 'kik', 'kikmeguy', 'kissm', 'nude', 'likeforfollow', 'musicbiz', 'sexysasunday']
# 1	0.49967610	b'add kik ughtmed545 kik kikmeguy kissm nude likeforfollow musicbiz sexysasunday'
# THE TWEET IS: Snapchat me : sexyjudy19 #snapchat #kikmeboys #tagsforlikes #pussy #gay #indiemusic #sexo :) http://t.co/KzdArKKieg
# THE PROCESSED TWEET IS: ['snapchat', 'sexyjudy19', 'snapchat', 'kikmeboy', 'tagsforlik', 'pussi', 'gay', 'indiemus', 'sexo']
# 1	0.49988611	b'snapchat sexyjudy19 snapchat kikmeboy tagsforlik pussi gay indiemus sexo'
# THE TWEET IS: @yknoC that monte/doa header :D
# THE PROCESSED TWEET IS: ['montedoa', 'header']
# 1	0.49998770	b'montedoa header'
# THE TWEET IS: i'm in amsterdam guys wooo :D
# THE PROCESSED TWEET IS: ['im', 'amsterdam', 'guy', 'wooo']
# 1	0.49971451	b'im amsterdam guy wooo'
# THE TWEET IS: @MatjazSircelj stuff just happens. :)
# THE PROCESSED TWEET IS: ['stuff', 'happen']
# 1	0.49992969	b'stuff happen'
# THE TWEET IS: @NAYAKHK 2)IndiraG wanted Judiciary to be committed to Govt policy. Now they want RBI to be committed. But I know many have similar views :)
# THE PROCESSED TWEET IS: ['2indirag', 'want', 'judiciari', 'commit', 'govt', 'polici', 'want', 'rbi', 'commit', 'know', 'mani', 'similar', 'view']
# 1	0.49984173	b'2indirag want judiciari commit govt polici want rbi commit know mani similar view'
# THE TWEET IS: @1RobBeasley any progress in Stones transfer to Chelsea ?? :D
# THE PROCESSED TWEET IS: ['progress', 'stone', 'transfer', 'chelsea']
# 1	0.49999966	b'progress stone transfer chelsea'
# THE TWEET IS: @PoemPorns hah....and a thousand more lies  :D
# THE PROCESSED TWEET IS: ['hahand', 'thousand', 'lie']
# 1	0.49998953	b'hahand thousand lie'
# THE TWEET IS: So Im going to sleep Goodnight :)
# THE PROCESSED TWEET IS: ['im', 'go', 'sleep', 'goodnight']
# 1	0.49970477	b'im go sleep goodnight'
# THE TWEET IS: @ABNORMAL_ANA92 i'm supposed to ask where do you buy albums :)
# THE PROCESSED TWEET IS: ['im', 'suppos', 'ask', 'buy', 'album']
# 1	0.49966782	b'im suppos ask buy album'
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/R2JBO8iNww http://t.co/ow5BBwdEMY
# THE PROCESSED TWEET IS: ['im', 'play', 'brain', 'dot', 'braindot']
# 1	0.49986471	b'im play brain dot braindot'
# THE TWEET IS: @IGNUK #1TBPS4 Wow! what a prize! so delightful for my eyes, pick me to win and I will burst and sing "PS4 is mine and I feel divine" :)
# THE PROCESSED TWEET IS: ['1tbps4', 'wow', 'prize', 'delight', 'eye', 'pick', 'win', 'burst', 'sing', 'ps4', 'mine', 'feel', 'divin']
# 1	0.49977560	b'1tbps4 wow prize delight eye pick win burst sing ps4 mine feel divin'
# THE TWEET IS: https://t.co/gBIMDzQBY5 Must watch :D #BajrangiBhaijaanHighestWeek1
# THE PROCESSED TWEET IS: []
# 1	0.50000000	b''
# THE TWEET IS: @justinbieber YOU ARE DADDY AF... :-)
# THE PROCESSED TWEET IS: ['daddi', 'af']
# 1	0.49999717	b'daddi af'
# THE TWEET IS: @kavonyo okay yay! Ask tomorrow please :)
# THE PROCESSED TWEET IS: ['okay', 'yay', 'ask', 'tomorrow', 'pleas']
# 1	0.49986492	b'okay yay ask tomorrow pleas'
# THE TWEET IS: @bridgetminamore I voted for #brainchild 3 times, please may I have a poem? :D
# THE PROCESSED TWEET IS: ['vote', 'brainchild', '3', 'time', 'pleas', 'may', 'poem']
# 1	0.49974342	b'vote brainchild 3 time pleas may poem'
# THE TWEET IS: @DanielNewman Wishing you were in Colorado :)
# THE PROCESSED TWEET IS: ['wish', 'colorado']
# 1	0.49990260	b'wish colorado'
# THE TWEET IS: @machado_man4 @TashaShukla @CloydRivers and freedom to hangout with whoever you want to!!!!!!!!! :)
# THE PROCESSED TWEET IS: ['freedom', 'hangout', 'whoever', 'want']
# 1	0.49955363	b'freedom hangout whoever want'
# THE TWEET IS: @GreggsOfficial I missed you baby :) #onemochaonelove
# THE PROCESSED TWEET IS: ['miss', 'babi', 'onemochaonelov']
# 1	0.49862348	b'miss babi onemochaonelov'
# THE TWEET IS: Yup, happen everywhere when people cant debate they come to name calling :-)  https://t.co/dRiMWpj7ON
# THE PROCESSED TWEET IS: ['yup', 'happen', 'everywher', 'peopl', 'cant', 'debat', 'come', 'name', 'call']
# 1	0.49964457	b'yup happen everywher peopl cant debat come name call'
# THE TWEET IS: I WANT to create the FIRST #Bboying #Cardgame with #pixelart #gamedesign :D!!!! What do you think ?? #indiedev #pixel_dailies #gamedev
# THE PROCESSED TWEET IS: ['want', 'creat', 'first', 'bboy', 'cardgam', 'pixelart', 'gamedesign', 'think', 'indiedev', 'pixeldaili', 'gamedev']
# 1	0.49998375	b'want creat first bboy cardgam pixelart gamedesign think indiedev pixeldaili gamedev'
# THE TWEET IS: Mans singing under the rain :) https://t.co/uj3mnLaJmo
# THE PROCESSED TWEET IS: ['man', 'sing', 'rain']
# 1	0.49995511	b'man sing rain'
# THE TWEET IS: @melfoster666 That's not true.
# I can quit whenever I want to.
# :D
# THE PROCESSED TWEET IS: ['that', 'true', 'quit', 'whenev', 'want']
# 1	0.49998009	b'that true quit whenev want'
# THE TWEET IS: Family hang out :) ^_^ — feeling festive at Jamuna Future Park http://t.co/CXQXINIqJI
# THE PROCESSED TWEET IS: ['famili', 'hang', '—', 'feel', 'festiv', 'jamuna', 'futur', 'park']
# 1	0.49983227	b'famili hang  feel festiv jamuna futur park'
# THE TWEET IS: @pop_ruth you miss this! :-) http://t.co/upXtepl57y
# THE PROCESSED TWEET IS: ['miss']
# 1	0.49869278	b'miss'
# THE TWEET IS: @vadervanodin im wearing mine when I dj next fri :-)
# THE PROCESSED TWEET IS: ['im', 'wear', 'mine', 'dj', 'next', 'fri']
# 1	0.49972614	b'im wear mine dj next fri'
# THE TWEET IS: @DailyBBLife @JulizTwinsBB he already does :)
# THE PROCESSED TWEET IS: ['alreadi']
# 1	0.49994050	b'alreadi'
# THE TWEET IS: I'm that person that has to workout and eat healthy because the minute I don't I gain weight :-)
# THE PROCESSED TWEET IS: ['im', 'person', 'workout', 'eat', 'healthi', 'minut', 'dont', 'gain', 'weight']
# 1	0.49924820	b'im person workout eat healthi minut dont gain weight'
# THE TWEET IS: Bad Boys :) #burgers #melbourneburgers https://t.co/TyD88wr40d
# THE PROCESSED TWEET IS: ['bad', 'boy', 'burger', 'melbourneburg']
# 1	0.49992504	b'bad boy burger melbourneburg'
# THE TWEET IS: who wants to ft me and Arianna :-)
# THE PROCESSED TWEET IS: ['want', 'ft', 'arianna']
# 1	0.49959234	b'want ft arianna'
# THE TWEET IS: okkkk frends milte h break k bad :)
# THE PROCESSED TWEET IS: ['okkkk', 'frend', 'milt', 'h', 'break', 'k', 'bad']
# 1	0.49989862	b'okkkk frend milt h break k bad'
# THE TWEET IS: HOME ALONE :D
# THE PROCESSED TWEET IS: ['home', 'alon']
# 1	0.49981538	b'home alon'
# THE TWEET IS: Who wants to elevate from your position? Who wants a promotion! Who wants the favor of God and the favor of men... :) http://t.co/cOECx9BBNd
# THE PROCESSED TWEET IS: ['want', 'elev', 'posit', 'want', 'promot', 'want', 'favor', 'god', 'favor', 'men']
# 1	0.49891974	b'want elev posit want promot want favor god favor men'
# THE TWEET IS: I'm so insecure tonight :-)
# THE PROCESSED TWEET IS: ['im', 'insecur', 'tonight']
# 1	0.49953774	b'im insecur tonight'
# THE TWEET IS: @brianteeman @GW1992 I squashed the commits. Did it still make 200 commits? :)
# THE PROCESSED TWEET IS: ['squash', 'commit', 'still', 'make', '200', 'commit']
# 1	0.49986715	b'squash commit still make 200 commit'
# THE TWEET IS: 3hrs before.. :) tym to prepare
# THE PROCESSED TWEET IS: ['3hr', 'tym', 'prepar']
# 1	0.49999784	b'3hr tym prepar'
# THE TWEET IS: @MCunleashed :D I can't sleep until I need to. If I try I just lay in bed bored
# THE PROCESSED TWEET IS: ['cant', 'sleep', 'need', 'tri', 'lay', 'bed', 'bore']
# 1	0.49930229	b'cant sleep need tri lay bed bore'
# THE TWEET IS: @grillo_23 @sleepyjoe2 @Karnage90 @RichardDawkins Dear person, please study before embarrassing urself. Entropy works 100% w/ evolution :)
# THE PROCESSED TWEET IS: ['dear', 'person', 'pleas', 'studi', 'embarrass', 'urself', 'entropi', 'work', '100', 'w', 'evolut']
# 1	0.49976287	b'dear person pleas studi embarrass urself entropi work 100 w evolut'
# THE TWEET IS: @chordoverstreet just seen this at uni.. He has more talents :) http://t.co/eNq3XuOPSN
# THE PROCESSED TWEET IS: ['seen', 'uni', 'talent']
# 1	0.49997440	b'seen uni talent'
# THE TWEET IS: @msarosh Uff Itna Miss karhy thy ap :p
# THE PROCESSED TWEET IS: ['uff', 'itna', 'miss', 'karhi', 'thi', 'ap', 'p']
# 1	0.49973238	b'uff itna miss karhi thi ap p'
# THE TWEET IS: @JonsCrazyTweets still more green tea blends with other flavors. :)
# THE PROCESSED TWEET IS: ['still', 'green', 'tea', 'blend', 'flavor']
# 1	0.49972048	b'still green tea blend flavor'
# <ipython-input-64-6eb8e65380e7>:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# THE TWEET IS: Evolution ! :D http://t.co/6el4C2C0uF
# THE PROCESSED TWEET IS: ['evolut']
# 1	0.50000000	b'evolut'
# THE TWEET IS: @SwgGuy Hah.... :D
# Don't say sorry...
# THE PROCESSED TWEET IS: ['hah', 'dont', 'say', 'sorri']
# 1	0.49925730	b'hah dont say sorri'
# THE TWEET IS: @chewy4cutie but you can with me :)
# THE PROCESSED TWEET IS: []
# 1	0.50000000	b''
# THE TWEET IS: Ltsw here we gooooooo! :-)
# THE PROCESSED TWEET IS: ['ltsw', 'gooooooo']
# 1	0.50000000	b'ltsw gooooooo'
# THE TWEET IS: @aleeshajulia @IAPI_Updates that is a giant balloon! I want one :)
# THE PROCESSED TWEET IS: ['giant', 'balloon', 'want', 'one']
# 1	0.49975660	b'giant balloon want one'
# THE TWEET IS: @aatishn  carpe diem Mr Nath :)
# THE PROCESSED TWEET IS: ['carp', 'diem', 'mr', 'nath']
# 1	0.49999750	b'carp diem mr nath'
# THE TWEET IS: me: as long as i feel comfortable im gonna wear what i want
# my mother: haha...that sounds nice...but no :-)
# THE PROCESSED TWEET IS: ['long', 'feel', 'comfort', 'im', 'gonna', 'wear', 'want', 'mother', 'hahathat', 'sound', 'nicebut']
# 1	0.49868237	b'long feel comfort im gonna wear want mother hahathat sound nicebut'
# THE TWEET IS: idk but cant wait for tonights panel to be up for people :)
# THE PROCESSED TWEET IS: ['idk', 'cant', 'wait', 'tonight', 'panel', 'peopl']
# 1	0.49965026	b'idk cant wait tonight panel peopl'
# THE TWEET IS: I'am ELF, hbu? :)
# THE PROCESSED TWEET IS: ['iam', 'elf', 'hbu']
# 1	0.49999169	b'iam elf hbu'
# THE TWEET IS: @thevieweast Of course! Now I've been cited in an academic paper I feel I've arrived :-)
# THE PROCESSED TWEET IS: ['cours', 'ive', 'cite', 'academ', 'paper', 'feel', 'ive', 'arriv']
# 1	0.49971856	b'cours ive cite academ paper feel ive arriv'
# THE TWEET IS: Who's still awake ?:)))
# THE PROCESSED TWEET IS: ['who', 'still', 'awak']
# 1	0.49979541	b'who still awak'
# THE TWEET IS: @realyys_ OTL NEVERMIND :( at least i got jeon so
# THE PROCESSED TWEET IS: ['otl', 'nevermind', 'least', 'got', 'jeon']
# 0	0.50011094	b'otl nevermind least got jeon'
# THE TWEET IS: And AS SOON as I tweeted that she planted her claws in my thigh for traction and zoomed away :(
# THE PROCESSED TWEET IS: ['soon', 'tweet', 'plant', 'claw', 'thigh', 'traction', 'zoom', 'away']
# 0	0.50044174	b'soon tweet plant claw thigh traction zoom away'
# THE TWEET IS: @KLM I used to be PRY/PV ..... wish I could relive those days and become NYC/PV buy there is no way to communicate with NYC or USA KLM :(
# THE PROCESSED TWEET IS: ['use', 'prypv', 'wish', 'could', 'reliv', 'day', 'becom', 'nycpv', 'buy', 'way', 'commun', 'nyc', 'usa', 'klm']
# 0	0.50165187	b'use prypv wish could reliv day becom nycpv buy way commun nyc usa klm'
# THE TWEET IS: It's really hot :-(
# THE PROCESSED TWEET IS: ['realli', 'hot']
# 0	0.50016277	b'realli hot'
# THE TWEET IS: @Carouselballet Monday? :(
# THE PROCESSED TWEET IS: ['monday']
# 0	0.50002791	b'monday'
# THE TWEET IS: @blairforce2 which means its on its way over here :( 3rd load just hung up
# THE PROCESSED TWEET IS: ['mean', 'way', '3rd', 'load', 'hung']
# 0	0.50006160	b'mean way 3rd load hung'
# THE TWEET IS: English weather needs to fix up :((
# THE PROCESSED TWEET IS: ['english', 'weather', 'need', 'fix']
# 0	0.50003034	b'english weather need fix'
# THE TWEET IS: Live fam bam but I have a cough :(
# THE PROCESSED TWEET IS: ['live', 'fam', 'bam', 'cough']
# 0	0.50050840	b'live fam bam cough'
# THE TWEET IS: Absolutely gutted all the James Bay tickets have sold out for Manchester :(
# THE PROCESSED TWEET IS: ['absolut', 'gut', 'jame', 'bay', 'ticket', 'sold', 'manchest']
# 0	0.50005448	b'absolut gut jame bay ticket sold manchest'
# THE TWEET IS: @missalicebmbds it's sore, Alice. :(
# THE PROCESSED TWEET IS: ['sore', 'alic']
# 0	0.50006048	b'sore alic'
# THE TWEET IS: @adoringpreston someone unfaved :((
# THE PROCESSED TWEET IS: ['someon', 'unfav']
# 0	0.50003570	b'someon unfav'
# THE TWEET IS: @infinityandbion funny mo :(
# THE PROCESSED TWEET IS: ['funni', 'mo']
# 0	0.50013541	b'funni mo'
# THE TWEET IS: someone explain #SandraBland :(
# THE PROCESSED TWEET IS: ['someon', 'explain', 'sandrabland']
# 0	0.50003138	b'someon explain sandrabland'
# THE TWEET IS: @sonzhi No, I am going to spend the night in Prague and then leaving tomorrow :(
# THE PROCESSED TWEET IS: ['go', 'spend', 'night', 'pragu', 'leav', 'tomorrow']
# 0	0.50052672	b'go spend night pragu leav tomorrow'
# THE TWEET IS: one of my friend is following me , a little heart attack , im sorry youre blocked :((((( sadis
# THE PROCESSED TWEET IS: ['one', 'friend', 'follow', 'littl', 'heart', 'attack', 'im', 'sorri', 'your', 'block', 'sadi']
# 0	0.50172929	b'one friend follow littl heart attack im sorri your block sadi'
# THE TWEET IS: @SarahLucero boo. I had already turned in. Yes. At 915. :(
# THE PROCESSED TWEET IS: ['boo', 'alreadi', 'turn', 'ye', '915']
# 0	0.50032195	b'boo alreadi turn ye 915'
# THE TWEET IS: my layout doesn't match but it's the closest I could find for my header :( someone help
# THE PROCESSED TWEET IS: ['layout', 'doesnt', 'match', 'closest', 'could', 'find', 'header', 'someon', 'help']
# 0	0.50006851	b'layout doesnt match closest could find header someon help'
# THE TWEET IS: @RamaZafar hayeee :( hayeee :( patwari here mam but for IK's vision I would say nothing rather than a lil laugh
# THE PROCESSED TWEET IS: ['hayee', 'hayee', 'patwari', 'mam', 'ik', 'vision', 'would', 'say', 'noth', 'rather', 'lil', 'laugh']
# 0	0.50058494	b'hayee hayee patwari mam ik vision would say noth rather lil laugh'
# THE TWEET IS: @TheKelseeey awhhh ok ok :( see you nalang when class opens!!! Hehe
# THE PROCESSED TWEET IS: ['awhhh', 'ok', 'ok', 'see', 'nalang', 'class', 'open', 'hehe']
# 0	0.50127145	b'awhhh ok ok see nalang class open hehe'
# THE TWEET IS: Last night was one of the worst night :( I pretty sure this Albanian women cursed me
# THE PROCESSED TWEET IS: ['last', 'night', 'one', 'worst', 'night', 'pretti', 'sure', 'albanian', 'women', 'curs']
# 0	0.50132490	b'last night one worst night pretti sure albanian women curs'
# THE TWEET IS: @ChaeHyungwon_ taken :( another chara maybe? -teteh
# THE PROCESSED TWEET IS: ['taken', 'anoth', 'chara', 'mayb', 'teteh']
# 0	0.50008023	b'taken anoth chara mayb teteh'
# THE TWEET IS: @ryannhough I can imagine! This would shatter my dreams :-( We'll let our @CooperativeFood colleagues know all about this. ^SB
# THE PROCESSED TWEET IS: ['imagin', 'would', 'shatter', 'dream', 'well', 'let', 'colleagu', 'know', 'sb']
# 0	0.50205163	b'imagin would shatter dream well let colleagu know sb'
# THE TWEET IS: Wanna feel loved :(
# THE PROCESSED TWEET IS: ['wanna', 'feel', 'love']
# 0	0.50190141	b'wanna feel love'
# THE TWEET IS: I'm sorry I didn't see this tweet :( 2 Points x https://t.co/N6HMgKfoR1
# THE PROCESSED TWEET IS: ['im', 'sorri', 'didnt', 'see', 'tweet', '2', 'point', 'x']
# 0	0.50038823	b'im sorri didnt see tweet 2 point x'
# THE TWEET IS: can i hav my purity back ? :(
# THE PROCESSED TWEET IS: ['hav', 'puriti', 'back']
# 0	0.50014749	b'hav puriti back'
# THE TWEET IS: 3 days without talking with Bae :(
# THE PROCESSED TWEET IS: ['3', 'day', 'without', 'talk', 'bae']
# 0	0.50131796	b'3 day without talk bae'
# THE TWEET IS: Nakakapikon yung nagbabasa ka ng blog comments for info and it's full of people asking the same damned questions answered in the post. :(
# THE PROCESSED TWEET IS: ['nakakapikon', 'yung', 'nagbabasa', 'ka', 'ng', 'blog', 'comment', 'info', 'full', 'peopl', 'ask', 'damn', 'question', 'answer', 'post']
# 0	0.50090677	b'nakakapikon yung nagbabasa ka ng blog comment info full peopl ask damn question answer post'
# THE TWEET IS: @kevinperry leading cause of cancer in children under five :(
# THE PROCESSED TWEET IS: ['lead', 'caus', 'cancer', 'children', 'five']
# 0	0.50008622	b'lead caus cancer children five'
# THE TWEET IS: @rcdlccom hello, any info about possible interest in Jonathas ?? He is close to join Betis :( greatings
# THE PROCESSED TWEET IS: ['hello', 'info', 'possibl', 'interest', 'jonatha', 'close', 'join', 'beti', 'great']
# 0	0.50217353	b'hello info possibl interest jonatha close join beti great'
# THE TWEET IS: @lucyanne_l Thank you for sending premium writing instrument, however some dastardly swine stole it from envelope! :( http://t.co/xNe3cD6dvk
# THE PROCESSED TWEET IS: ['thank', 'send', 'premium', 'write', 'instrument', 'howev', 'dastardli', 'swine', 'stole', 'envelop']
# 0	0.50468905	b'thank send premium write instrument howev dastardli swine stole envelop'
# THE TWEET IS: @Charlie_Bread fair enough :( why would anyone do that? Just seems a tad fucked up 😔 .. It's a wiper, a wiper!
# THE PROCESSED TWEET IS: ['fair', 'enough', 'would', 'anyon', 'seem', 'tad', 'fuck', '😔', 'wiper', 'wiper']
# 0	0.50031394	b'fair enough would anyon seem tad fuck  wiper wiper'
# THE TWEET IS: @EMPERYtech supposedly one of the worst kernels for any device :(
# THE PROCESSED TWEET IS: ['supposedli', 'one', 'worst', 'kernel', 'devic']
# 0	0.50016575	b'supposedli one worst kernel devic'
# THE TWEET IS: Today’s job (another facking #Intel). Extra mega careful not to get bent socket pins :-( #PCGaming #PCUpgrade http://t.co/VeJNS9FBfn
# THE PROCESSED TWEET IS: ['today’', 'job', 'anoth', 'fack', 'intel', 'extra', 'mega', 'care', 'get', 'bent', 'socket', 'pin', 'pcgame', 'pcupgrad']
# 0	0.50105743	b'today job anoth fack intel extra mega care get bent socket pin pcgame pcupgrad'
# THE TWEET IS: is everyone asleep already?:((((
# THE PROCESSED TWEET IS: ['everyon', 'asleep', 'alreadi']
# 0	0.50024005	b'everyon asleep alreadi'
# THE TWEET IS: can some1 pls download smosh:the movie free online? Hahahaha :(
# THE PROCESSED TWEET IS: ['some1', 'pl', 'download', 'smoshth', 'movi', 'free', 'onlin', 'hahahaha']
# 0	0.50023822	b'some1 pl download smoshth movi free onlin hahahaha'
# THE TWEET IS: @rivverofhoney Omg no way?! not you guys aswell :-( btw cat litter isnt good for pregnancy make sure u dont go near
# THE PROCESSED TWEET IS: ['omg', 'way', 'guy', 'aswel', 'btw', 'cat', 'litter', 'isnt', 'good', 'pregnanc', 'make', 'sure', 'u', 'dont', 'go', 'near']
# 0	0.50213207	b'omg way guy aswel btw cat litter isnt good pregnanc make sure u dont go near'
# THE TWEET IS: Ah Mensch @Tikus09 :(
# THE PROCESSED TWEET IS: ['ah', 'mensch']
# 0	0.50002940	b'ah mensch'
# THE TWEET IS: Sepanx with this one :( https://t.co/4Hp6d3sMwr
# THE PROCESSED TWEET IS: ['sepanx', 'one']
# 0	0.50019899	b'sepanx one'
# THE TWEET IS: @LoseThe_Battle We cannot view the picture. Are you unhappy with the seats on our bus? :(
# THE PROCESSED TWEET IS: ['cannot', 'view', 'pictur', 'unhappi', 'seat', 'bu']
# 0	0.50007292	b'cannot view pictur unhappi seat bu'
# THE TWEET IS: @baexrv pcy mine :-(
# THE PROCESSED TWEET IS: ['pci', 'mine']
# 0	0.50004386	b'pci mine'
# THE TWEET IS: @walesdotcom @Visitcaerphilly last time I went to Caerphilly I couldn't find anywhere selling local cheese :-(
# THE PROCESSED TWEET IS: ['last', 'time', 'went', 'caerphilli', 'couldnt', 'find', 'anywher', 'sell', 'local', 'chees']
# 0	0.50009922	b'last time went caerphilli couldnt find anywher sell local chees'
# THE TWEET IS: Never seeing your dad until midnight bc he worked hard as fuck :( #GrowingUpPoor
# THE PROCESSED TWEET IS: ['never', 'see', 'dad', 'midnight', 'bc', 'work', 'hard', 'fuck', 'growinguppoor']
# 0	0.50089137	b'never see dad midnight bc work hard fuck growinguppoor'
# THE TWEET IS: @JackJackJohnson @jackgilinsky NUMBER ONE IN AMERICA!! 😭🇺🇸
# i wish i could buy it but no money :( http://t.co/7xyNmimTpR
# THE PROCESSED TWEET IS: ['number', 'one', 'america', '😭🇺🇸', 'wish', 'could', 'buy', 'money']
# 0	0.50008361	b'number one america  wish could buy money'
# THE TWEET IS: @literalwt tyas mind to refollow me :(
# THE PROCESSED TWEET IS: ['tya', 'mind', 'refollow']
# 0	0.50010716	b'tya mind refollow'
# THE TWEET IS: ksoo u dumb butt :(
# THE PROCESSED TWEET IS: ['ksoo', 'u', 'dumb', 'butt']
# 0	0.50043191	b'ksoo u dumb butt'
# THE TWEET IS: i want to finish death parade by this weekend :(
# THE PROCESSED TWEET IS: ['want', 'finish', 'death', 'parad', 'weekend']
# 0	0.50015358	b'want finish death parad weekend'
# THE TWEET IS: RIP TOM MOORE...... I LOVE READING HIS COMIC BOOKS....
# ANOTHER GREAT ARTIST I WILL TRULY MISS  :( http://t.co/f5uVxTUcSE
# THE PROCESSED TWEET IS: ['rip', 'tom', 'moor', 'love', 'read', 'comic', 'book', 'anoth', 'great', 'artist', 'truli', 'miss']
# 0	0.50281598	b'rip tom moor love read comic book anoth great artist truli miss'
# THE TWEET IS: when can sch get better........ :-(
# THE PROCESSED TWEET IS: ['sch', 'get', 'better']
# 0	0.50075803	b'sch get better'
# THE TWEET IS: Why is no one awake :(
# THE PROCESSED TWEET IS: ['one', 'awak']
# 0	0.50023089	b'one awak'
# THE TWEET IS: Get in the bin, OSX/Chrome/Voiceover &gt;:( http://t.co/0bcvA6YjWu
# THE PROCESSED TWEET IS: ['get', 'bin', 'osxchromevoiceov', 'gt']
# 0	0.50036791	b'get bin osxchromevoiceov gt'
# THE TWEET IS: 😂😂 what a night :(((((( so devo xxx https://t.co/9ixTnyBXLb
# THE PROCESSED TWEET IS: ['😂😂', 'night', 'devo', 'xxx']
# 0	0.50043313	b' night devo xxx'
# THE TWEET IS: I hope it's wrong about #HulkHogan but I think I know deep down its not. It's hurtful to wake up that kind of unpleasantness :(
# THE PROCESSED TWEET IS: ['hope', 'wrong', 'hulkhogan', 'think', 'know', 'deep', 'hurt', 'wake', 'kind', 'unpleas']
# 0	0.50112980	b'hope wrong hulkhogan think know deep hurt wake kind unpleas'
# THE TWEET IS: @Yoonginese I don't even know what to say :(((
# THE PROCESSED TWEET IS: ['dont', 'even', 'know', 'say']
# 0	0.50031848	b'dont even know say'
# THE TWEET IS: @maaaybs Grabe ang harsh huhuhu why u like that? :(
# THE PROCESSED TWEET IS: ['grabe', 'ang', 'harsh', 'huhuhu', 'u', 'like']
# 0	0.50119378	b'grabe ang harsh huhuhu u like'
# THE TWEET IS: Dadas uh iphone na, :(:( [pic] — https://t.co/Jr4U98A8ja
# THE PROCESSED TWEET IS: ['dada', 'uh', 'iphon', 'na', 'pic', '—']
# 0	0.50021713	b'dada uh iphon na pic '
# THE TWEET IS: @ssulstagram why you unfollow me unnie?:(
# THE PROCESSED TWEET IS: ['unfollow', 'unni']
# 0	0.50049196	b'unfollow unni'
# THE TWEET IS: @norman__g lucky spike only :-(
# THE PROCESSED TWEET IS: ['lucki', 'spike']
# 0	0.50000332	b'lucki spike'
# THE TWEET IS: Why didn't Panic's new album come out on the 22nd :(
# THE PROCESSED TWEET IS: ['didnt', 'panic', 'new', 'album', 'come', '22nd']
# 0	0.50073228	b'didnt panic new album come 22nd'
# THE TWEET IS: bigbang need some rest :( they have been travelling from one place to another, must be really tiring for them :(
# THE PROCESSED TWEET IS: ['bigbang', 'need', 'rest', 'travel', 'one', 'place', 'anoth', 'must', 'realli', 'tire']
# 0	0.50049957	b'bigbang need rest travel one place anoth must realli tire'
# THE TWEET IS: @nickiminaj you mention South Africa so many times in your song its about time you come to South Africa ! :(
# THE PROCESSED TWEET IS: ['mention', 'south', 'africa', 'mani', 'time', 'song', 'time', 'come', 'south', 'africa']
# 0	0.50096597	b'mention south africa mani time song time come south africa'
# THE TWEET IS: Hate when I can't remember my dreams, I love sharing them :(
# THE PROCESSED TWEET IS: ['hate', 'cant', 'rememb', 'dream', 'love', 'share']
# 0	0.50217286	b'hate cant rememb dream love share'
# THE TWEET IS: What is going on in America man R.I.P to all the victims in #Louisiana :(
# THE PROCESSED TWEET IS: ['go', 'america', 'man', 'rip', 'victim', 'louisiana']
# 0	0.50007250	b'go america man rip victim louisiana'
# THE TWEET IS: When school comes between me and twitter :(
# THE PROCESSED TWEET IS: ['school', 'come', 'twitter']
# 0	0.50029237	b'school come twitter'
# THE TWEET IS: Taking 190 at such a horrible timing :(
# THE PROCESSED TWEET IS: ['take', '190', 'horribl', 'time']
# 0	0.50025213	b'take 190 horribl time'
# THE TWEET IS: @myungfart ella :( cheer up pls
# THE PROCESSED TWEET IS: ['ella', 'cheer', 'pl']
# 0	0.50006096	b'ella cheer pl'
# THE TWEET IS: @Lizarrdz That's no excuse for launching an attack Lizardz, you should feel like shit for doing that.  I am deeply ashamed of you.  &gt;:(
# THE PROCESSED TWEET IS: ['that', 'excus', 'launch', 'attack', 'lizardz', 'feel', 'like', 'shit', 'deepli', 'asham', 'gt']
# 0	0.50043492	b'that excus launch attack lizardz feel like shit deepli asham gt'
# THE TWEET IS: @cockneyradish Sorry about that :( We need to get an emergency engineer out to you! Will you be home for the next 4 hours? ^Laura
# THE PROCESSED TWEET IS: ['sorri', 'need', 'get', 'emerg', 'engin', 'home', 'next', '4', 'hour', 'laura']
# 0	0.50030862	b'sorri need get emerg engin home next 4 hour laura'
# THE TWEET IS: I can never go to sleep early :( lol
# THE PROCESSED TWEET IS: ['never', 'go', 'sleep', 'earli', 'lol']
# 0	0.50037716	b'never go sleep earli lol'
# THE TWEET IS: @JDRaPlD @Excluzzive I was talking to exclusive :( U know I carry U want me to play 😘
# THE PROCESSED TWEET IS: ['talk', 'exclus', 'u', 'know', 'carri', 'u', 'want', 'play', '😘']
# 0	0.50126040	b'talk exclus u know carri u want play '
# THE TWEET IS: 7pm on a Friday and I am dead :(
# THE PROCESSED TWEET IS: ['7pm', 'friday', 'dead']
# 0	0.50084204	b'7pm friday dead'
# THE TWEET IS: @Shansdoe every time i have feta cheese, my head starts to blaaaaze! sometimes my vision is messed too and nausea comes in :(
# THE PROCESSED TWEET IS: ['everi', 'time', 'feta', 'chees', 'head', 'start', 'blaaaaz', 'sometim', 'vision', 'mess', 'nausea', 'come']
# 0	0.50093976	b'everi time feta chees head start blaaaaz sometim vision mess nausea come'
# THE TWEET IS: @natzaz17 Oh no, that's not good :( We're not aware of any issues. Have you been able to top-up now?
# THE PROCESSED TWEET IS: ['oh', 'that', 'good', 'awar', 'issu', 'abl', 'topup']
# 0	0.50164210	b'oh that good awar issu abl topup'
# THE TWEET IS: Sharknado, one hour that I will never get back :(
# THE PROCESSED TWEET IS: ['sharknado', 'one', 'hour', 'never', 'get', 'back']
# 0	0.50104136	b'sharknado one hour never get back'
# THE TWEET IS: Yeah, leave me on read :-(
# THE PROCESSED TWEET IS: ['yeah', 'leav', 'read']
# 0	0.50019735	b'yeah leav read'
# THE TWEET IS: I cannot even sleep right now :(
# THE PROCESSED TWEET IS: ['cannot', 'even', 'sleep', 'right']
# 0	0.50001321	b'cannot even sleep right'
# THE TWEET IS: Looking for fun? SNAPCHAT : LilyButle18 #snapchat #kikmenow #amateur #kikmeboys #seduce #hannibal #kiksexting :( http://t.co/y8RcKiqSZ3
# THE PROCESSED TWEET IS: ['look', 'fun', 'snapchat', 'lilybutle18', 'snapchat', 'kikmenow', 'amateur', 'kikmeboy', 'seduc', 'hannib', 'kiksext']
# 0	0.50084109	b'look fun snapchat lilybutle18 snapchat kikmenow amateur kikmeboy seduc hannib kiksext'
# THE TWEET IS: when ed sheeran is preforming in your country tonight and ur not going :(
# THE PROCESSED TWEET IS: ['ed', 'sheeran', 'preform', 'countri', 'tonight', 'ur', 'go']
# 0	0.50047507	b'ed sheeran preform countri tonight ur go'
# THE TWEET IS: @Uber_Mumbai Cannot seem to get one in Powai! :(
# THE PROCESSED TWEET IS: ['cannot', 'seem', 'get', 'one', 'powai']
# 0	0.50076147	b'cannot seem get one powai'
# THE TWEET IS: My neighbor doesn't let me sleep :-(
# THE PROCESSED TWEET IS: ['neighbor', 'doesnt', 'let', 'sleep']
# 0	0.50050602	b'neighbor doesnt let sleep'
# THE TWEET IS: @The_Lie_Lama back to Delhi :(
# THE PROCESSED TWEET IS: ['back', 'delhi']
# 0	0.50016377	b'back delhi'
# THE TWEET IS: @ButtCupboard my feet were cold!!!! and there was no point in taking the socks off okay stop :(
# THE PROCESSED TWEET IS: ['feet', 'cold', 'point', 'take', 'sock', 'okay', 'stop']
# 0	0.50013136	b'feet cold point take sock okay stop'
# THE TWEET IS: @crushinghes the summer holidays are great but I'm so bored already :(
# THE PROCESSED TWEET IS: ['summer', 'holiday', 'great', 'im', 'bore', 'alreadi']
# 0	0.50071238	b'summer holiday great im bore alreadi'
# THE TWEET IS: @X2raw_evicted Oh. I was planning on streaming Halo on Xbox One today.  :(
# THE PROCESSED TWEET IS: ['oh', 'plan', 'stream', 'halo', 'xbox', 'one', 'today']
# 0	0.50065580	b'oh plan stream halo xbox one today'
# THE TWEET IS: Drop Dead Fred use to be my favorite movie
# I wish I had it :-(
# THE PROCESSED TWEET IS: ['drop', 'dead', 'fred', 'use', 'favorit', 'movi', 'wish']
# 0	0.50019217	b'drop dead fred use favorit movi wish'
# THE TWEET IS: remember was #2 on gaon and bad was #6 but infnt are eligible and apink are not :(((( acube why'd u do this
# THE PROCESSED TWEET IS: ['rememb', '2', 'gaon', 'bad', '6', 'infnt', 'elig', 'apink', 'acub', 'whyd', 'u']
# 0	0.50056279	b'rememb 2 gaon bad 6 infnt elig apink acub whyd u'
# THE TWEET IS: @iamcharleigh_ :( have fun
# THE PROCESSED TWEET IS: ['fun']
# 0	0.50033312	b'fun'
# THE TWEET IS: @Taylan247 :( - Do you know what happens to the internet light when the connection drops? Thanks, Kei.
# THE PROCESSED TWEET IS: ['know', 'happen', 'internet', 'light', 'connect', 'drop', 'thank', 'kei']
# 0	0.50503519	b'know happen internet light connect drop thank kei'
# THE TWEET IS: @HanaaGhzlli hanaaaa its your birthday???? ya Allah sorry for not wishing you in the van jn i tak tau :( happy birthday gorgeous!
# THE PROCESSED TWEET IS: ['hanaaaa', 'birthday', 'ya', 'allah', 'sorri', 'wish', 'van', 'jn', 'tak', 'tau', 'happi', 'birthday', 'gorgeou']
# 0	0.50191723	b'hanaaaa birthday ya allah sorri wish van jn tak tau happi birthday gorgeou'
# THE TWEET IS: And faith :(
# THE PROCESSED TWEET IS: ['faith']
# 0	0.50002426	b'faith'
# THE TWEET IS: What was the last present you received? — haha. basta. :( http://t.co/xhdfobhn8N
# THE PROCESSED TWEET IS: ['last', 'present', 'receiv', '—', 'haha', 'basta']
# 0	0.50058513	b'last present receiv  haha basta'
# THE TWEET IS: Snapchat me guys : JasminGarrick #snapchat #kiksexting #chat #sexting #addme #mpoints #hotmusicdelocos :( http://t.co/xXfTQWzhAI
# THE PROCESSED TWEET IS: ['snapchat', 'guy', 'jasmingarrick', 'snapchat', 'kiksext', 'chat', 'sext', 'addm', 'mpoint', 'hotmusicdeloco']
# 0	0.50013349	b'snapchat guy jasmingarrick snapchat kiksext chat sext addm mpoint hotmusicdeloco'
# THE TWEET IS: Relation full of lies :(
# THE PROCESSED TWEET IS: ['relat', 'full', 'lie']
# 0	0.50010832	b'relat full lie'
# THE TWEET IS: aw fuck there's a dress bag on the floor. dammit that's really loud :(
# THE PROCESSED TWEET IS: ['aw', 'fuck', 'there', 'dress', 'bag', 'floor', 'dammit', 'that', 'realli', 'loud']
# 0	0.50000651	b'aw fuck there dress bag floor dammit that realli loud'
# THE TWEET IS: Dhis👉 @AhmedMarzooq blocked my twitter :( thank you for the good time 😢 I play 8ball,  FAKMAREY,
# THE PROCESSED TWEET IS: ['dhis👉', 'block', 'twitter', 'thank', 'good', 'time', '😢', 'play', '8ball', 'fakmarey']
# 0	0.50632130	b'dhis block twitter thank good time  play 8ball fakmarey'
# THE TWEET IS: @LaEtchi unfortunately yours smells like doo doo :(
# THE PROCESSED TWEET IS: ['unfortun', 'smell', 'like', 'doo', 'doo']
# 0	0.50074525	b'unfortun smell like doo doo'
# THE TWEET IS: Shopping isn't fun when you're on your own :(
# THE PROCESSED TWEET IS: ['shop', 'isnt', 'fun', 'your']
# 0	0.50081276	b'shop isnt fun your'
# THE TWEET IS: I would like to be able to work full time on this stuff, but after this move, I'm having to consider taking on a fulltime job. :(
# THE PROCESSED TWEET IS: ['would', 'like', 'abl', 'work', 'full', 'time', 'stuff', 'move', 'im', 'consid', 'take', 'fulltim', 'job']
# 0	0.50168744	b'would like abl work full time stuff move im consid take fulltim job'
# THE TWEET IS: No food in the kitchen, no money in my wallet (thanks Barcelona) and my dad hasn't been home in a month so no beet juice either :(
# THE PROCESSED TWEET IS: ['food', 'kitchen', 'money', 'wallet', 'thank', 'barcelona', 'dad', 'hasnt', 'home', 'month', 'beet', 'juic', 'either']
# 0	0.50432299	b'food kitchen money wallet thank barcelona dad hasnt home month beet juic either'
# THE TWEET IS: DCI today, now I wish I was going :-(
# THE PROCESSED TWEET IS: ['dci', 'today', 'wish', 'go']
# 0	0.50037932	b'dci today wish go'
# THE TWEET IS: @TrevvyM114 At work and freezing :(
# THE PROCESSED TWEET IS: ['work', 'freez']
# 0	0.50024851	b'work freez'
# THE TWEET IS: Srsly, Y U do that? :((  https://t.co/g0r01GGj2b
# THE PROCESSED TWEET IS: ['srsli', 'u']
# 0	0.50041746	b'srsli u'
# THE TWEET IS: Hate seeing my granddad like this :(
# THE PROCESSED TWEET IS: ['hate', 'see', 'granddad', 'like']
# 0	0.50154918	b'hate see granddad like'
# THE TWEET IS: All is fair in love and war kapan update :(
#
# Oh ya udah dihapus. Hilang dari muka bumi.
#
# I want to read it once more someone give me link 😢
# THE PROCESSED TWEET IS: ['fair', 'love', 'war', 'kapan', 'updat', 'oh', 'ya', 'udah', 'dihapu', 'hilang', 'dari', 'muka', 'bumi', 'want', 'read', 'someon', 'give', 'link', '😢']
# 0	0.50284602	b'fair love war kapan updat oh ya udah dihapu hilang dari muka bumi want read someon give link '
# THE TWEET IS: @tiaramescudi girl that was so quick too :(
# THE PROCESSED TWEET IS: ['girl', 'quick']
# 0	0.50027630	b'girl quick'
# THE TWEET IS: so many nasty, narrow minded people :(
# THE PROCESSED TWEET IS: ['mani', 'nasti', 'narrow', 'mind', 'peopl']
# 0	0.50034289	b'mani nasti narrow mind peopl'
# THE TWEET IS: @RCDeportivo hello, any info about possible interest in Jonathas ?? He is close to join Betis :(
# THE PROCESSED TWEET IS: ['hello', 'info', 'possibl', 'interest', 'jonatha', 'close', 'join', 'beti']
# 0	0.50091779	b'hello info possibl interest jonatha close join beti'
# THE TWEET IS: @LizaNMinnelli i can't watch it on my phone. Sorry :( thank you still &lt;3
# THE PROCESSED TWEET IS: ['cant', 'watch', 'phone', 'sorri', 'thank', 'still', 'lt3']
# 0	0.50396677	b'cant watch phone sorri thank still lt3'
# THE TWEET IS: The taxi driver thought me and Sophie worked for Nintendo and took us into the gates :( the security guards gave us the dirtiest looks haha
# THE PROCESSED TWEET IS: ['taxi', 'driver', 'thought', 'sophi', 'work', 'nintendo', 'took', 'us', 'gate', 'secur', 'guard', 'gave', 'us', 'dirtiest', 'look', 'haha']
# 0	0.50261916	b'taxi driver thought sophi work nintendo took us gate secur guard gave us dirtiest look haha'
# THE TWEET IS: @1994sdork omg :-(( I LOVE YOU SO MUCH MONICA SEE YOU SOON AAAHHH !!!
# THE PROCESSED TWEET IS: ['omg', 'love', 'much', 'monica', 'see', 'soon', 'aaahhh']
# 0	0.50352425	b'omg love much monica see soon aaahhh'
# THE TWEET IS: :((( (at Crepes 40) — https://t.co/bazEmHlhYL
# THE PROCESSED TWEET IS: ['crepe', '40', '—']
# 0	0.50013042	b'crepe 40 '
# THE TWEET IS: @JoWaltham haha. Sounds like you’re having fun and games :(
# THE PROCESSED TWEET IS: ['haha', 'sound', 'like', 'you’r', 'fun', 'game']
# 0	0.50164076	b'haha sound like your fun game'
# THE TWEET IS: @justinbieber you don't follow me :(
# THE PROCESSED TWEET IS: ['dont', 'follow']
# 0	0.50141255	b'dont follow'
# THE TWEET IS: school is on monday but i don't wanna meet new people :(
# THE PROCESSED TWEET IS: ['school', 'monday', 'dont', 'wanna', 'meet', 'new', 'peopl']
# 0	0.50051984	b'school monday dont wanna meet new peopl'
# THE TWEET IS: @exhaustcd BUT... I HAVENT FINISHED YET :(
# THE PROCESSED TWEET IS: ['havent', 'finish', 'yet']
# 0	0.50004234	b'havent finish yet'
# THE TWEET IS: @bbomiyeh No. U forsaken me and ran off with the other gf. :(
# THE PROCESSED TWEET IS: ['u', 'forsaken', 'ran', 'gf']
# 0	0.50043773	b'u forsaken ran gf'
# THE TWEET IS: Can not get on #hypixel :( want to record grrrr #thestruggleisreal #geek #gamer #gamers #youtube
# THE PROCESSED TWEET IS: ['get', 'hypixel', 'want', 'record', 'grrrr', 'thestruggleisr', 'geek', 'gamer', 'gamer', 'youtub']
# 0	0.50023043	b'get hypixel want record grrrr thestruggleisr geek gamer gamer youtub'
# THE TWEET IS: this is a bummer :( apink's digital + physical sales have been super great but bc of the timing of the album release they aren't up to win?
# THE PROCESSED TWEET IS: ['bummer', 'apink', 'digit', 'physic', 'sale', 'super', 'great', 'bc', 'time', 'album', 'releas', 'arent', 'win']
# 0	0.50137393	b'bummer apink digit physic sale super great bc time album releas arent win'
# THE TWEET IS: but srsly tho, bae looks so out of it :((((
# THE PROCESSED TWEET IS: ['srsli', 'tho', 'bae', 'look']
# 0	0.50055804	b'srsli tho bae look'
# THE TWEET IS: @Cr4sh0v3rr1de Ahm...I've never been to London...nor on a holiday outside of Ireland in nearly 8 years :( Never got the chance/cash to go
# THE PROCESSED TWEET IS: ['ahmiv', 'never', 'londonnor', 'holiday', 'outsid', 'ireland', 'nearli', '8', 'year', 'never', 'got', 'chancecash', 'go']
# 0	0.50047464	b'ahmiv never londonnor holiday outsid ireland nearli 8 year never got chancecash go'
# THE TWEET IS: please follow me :( @JackJackJohnson
# THE PROCESSED TWEET IS: ['pleas', 'follow']
# 0	0.50105597	b'pleas follow'
# THE TWEET IS: 5am &amp; I'm up wit ha damn headache :(
# THE PROCESSED TWEET IS: ['5am', 'amp', 'im', 'wit', 'ha', 'damn', 'headach']
# 0	0.50061069	b'5am amp im wit ha damn headach'
# THE TWEET IS: I had a dream that I met Karlie Kloss &amp; she was so so sweet &amp; she wanted to take like a bunch of goofy photos with me. :(
# THE PROCESSED TWEET IS: ['dream', 'met', 'karli', 'kloss', 'amp', 'sweet', 'amp', 'want', 'take', 'like', 'bunch', 'goofi', 'photo']
# 0	0.50287423	b'dream met karli kloss amp sweet amp want take like bunch goofi photo'
# THE TWEET IS: i didn't realize it was 3 am i was watching concert videos and pcd is extremely hard rn :(
# THE PROCESSED TWEET IS: ['didnt', 'realiz', '3', 'watch', 'concert', 'video', 'pcd', 'extrem', 'hard', 'rn']
# 0	0.50000237	b'didnt realiz 3 watch concert video pcd extrem hard rn'
# THE TWEET IS: @helter_skeleton I haven't delved into it enough but what I have seen and heard is fucking horrendous. :(
# THE PROCESSED TWEET IS: ['havent', 'delv', 'enough', 'seen', 'heard', 'fuck', 'horrend']
# 0	0.50001074	b'havent delv enough seen heard fuck horrend'
# THE TWEET IS: @luke_brooks follow me :(
# THE PROCESSED TWEET IS: ['follow']
# 0	0.50172683	b'follow'
# THE TWEET IS: @AdaptsTheGod but duo we both dropped double digits :( TWICE
# THE PROCESSED TWEET IS: ['duo', 'drop', 'doubl', 'digit', 'twice']
# 0	0.50000082	b'duo drop doubl digit twice'
# THE TWEET IS: @DaShawnBullfrog @PapaHogieBear I just got here :( come!!!'
# THE PROCESSED TWEET IS: ['got', 'come']
# 0	0.50025097	b'got come'
# THE TWEET IS: THEYRE SO CUTE I WISH I KNEW WHAT THEY WERE SAYING :( http://t.co/Vr3ICTaFIS
# THE PROCESSED TWEET IS: ['theyr', 'cute', 'wish', 'knew', 'say']
# 0	0.50008631	b'theyr cute wish knew say'
# THE TWEET IS: I care :( http://t.co/Oe5ID3cJIR
# THE PROCESSED TWEET IS: ['care']
# 0	0.50004784	b'care'
# THE TWEET IS: My grandad really isn't well :( I worry so much about him!
# THE PROCESSED TWEET IS: ['grandad', 'realli', 'isnt', 'well', 'worri', 'much']
# 0	0.50046606	b'grandad realli isnt well worri much'
# ...
# 0	0.50101034	b'realli look forward work tonight though'
# THE TWEET IS: Going home blues this am :-( but back on MONDAY #hibye for social action plans @Herts1617 #ShareYourSummer http://t.co/7pJJ9q5v7z
# THE PROCESSED TWEET IS: ['go', 'home', 'blue', 'back', 'monday', 'hiby', 'social', 'action', 'plan', 'shareyoursumm']
# 0	0.50038778	b'go home blue back monday hiby social action plan shareyoursumm'
# THE TWEET IS: Being a pro soccer play would be so cool :(
# THE PROCESSED TWEET IS: ['pro', 'soccer', 'play', 'would', 'cool']
# 0	0.50081641	b'pro soccer play would cool'
# THE TWEET IS: @ITVCentral #Midlands Yes thanks for the depressing weather forecast, where the word 'rain' was mentioned several times :-(
# THE PROCESSED TWEET IS: ['midland', 'ye', 'thank', 'depress', 'weather', 'forecast', 'word', 'rain', 'mention', 'sever', 'time']
# 0	0.50516806	b'midland ye thank depress weather forecast word rain mention sever time'
# THE TWEET IS: @emergingrecruit @_RobLong You'll be this old one day..... :(
# THE PROCESSED TWEET IS: ['youll', 'old', 'one', 'day']
# 0	0.50144487	b'youll old one day'
# THE TWEET IS: literally spent all day yesterday sleeping on and off in bed, and I'm still absolutely fucking knackered today :((
# THE PROCESSED TWEET IS: ['liter', 'spent', 'day', 'yesterday', 'sleep', 'bed', 'im', 'still', 'absolut', 'fuck', 'knacker', 'today']
# 0	0.50061699	b'liter spent day yesterday sleep bed im still absolut fuck knacker today'
# THE TWEET IS: this new Sandra Bland footage is really the icing on the cake.. heartbreaking how they dragged her lifeless body from the police car :(
# THE PROCESSED TWEET IS: ['new', 'sandra', 'bland', 'footag', 'realli', 'ice', 'cake', 'heartbreak', 'drag', 'lifeless', 'bodi', 'polic', 'car']
# 0	0.50073560	b'new sandra bland footag realli ice cake heartbreak drag lifeless bodi polic car'
# THE TWEET IS: @jess_lakeland Sorry to hear this Jess :( The quickest way is to call +44 7782 333 333 or we can add this to your account within 72 hours:
# THE PROCESSED TWEET IS: ['sorri', 'hear', 'jess', 'quickest', 'way', 'call', '44', '7782', '333', '333', 'add', 'account', 'within', '72', 'hour']
# 0	0.50000834	b'sorri hear jess quickest way call 44 7782 333 333 add account within 72 hour'
# THE TWEET IS: Pengen boxing :( (at @golds_indonesia) — https://t.co/qXG4UNA4Fn
# THE PROCESSED TWEET IS: ['pengen', 'box', '—']
# 0	0.50010184	b'pengen box '
# THE TWEET IS: @Tanyastan4nicki girlll did u hear abt the possibly tsunami for us in West Indies?? Im in my island im afraid lol :((
# THE PROCESSED TWEET IS: ['girlll', 'u', 'hear', 'abt', 'possibl', 'tsunami', 'us', 'west', 'indi', 'im', 'island', 'im', 'afraid', 'lol']
# 0	0.50058418	b'girlll u hear abt possibl tsunami us west indi im island im afraid lol'
# THE TWEET IS: @BacheloretteABC @kaitlynbristowe would love to see her w/Nick but if she picks no one I waisted TV time. &amp; they never work out anyway. :(
# THE PROCESSED TWEET IS: ['would', 'love', 'see', 'wnick', 'pick', 'one', 'waist', 'tv', 'time', 'amp', 'never', 'work', 'anyway']
# 0	0.50587174	b'would love see wnick pick one waist tv time amp never work anyway'
# THE TWEET IS: Hulk Hogan in the news for a racial tirade :( I thought he couldnt stoop lower than his role in Thunder in Paradise http://t.co/vd0z6x8t8g
# THE PROCESSED TWEET IS: ['hulk', 'hogan', 'news', 'racial', 'tirad', 'thought', 'couldnt', 'stoop', 'lower', 'role', 'thunder', 'paradis']
# 0	0.50007673	b'hulk hogan news racial tirad thought couldnt stoop lower role thunder paradis'
# THE TWEET IS: .@aylesburyowl @ljam185 The facade of democracy has dropped so quickly :(
# THE PROCESSED TWEET IS: ['facad', 'democraci', 'drop', 'quickli']
# 0	0.50006845	b'facad democraci drop quickli'
# THE TWEET IS: Someone come over and I'll make popcorn and watch movies just pls cuddle me :(
# THE PROCESSED TWEET IS: ['someon', 'come', 'ill', 'make', 'popcorn', 'watch', 'movi', 'pl', 'cuddl']
# 0	0.50079717	b'someon come ill make popcorn watch movi pl cuddl'
# THE TWEET IS: @desiboy34783 @ArianaTorGlam Bade fursat se usey banaya hai usey uppar waale ney. Afsos humse dur hai wo :(
# THE PROCESSED TWEET IS: ['bade', 'fursat', 'se', 'usey', 'banaya', 'hai', 'usey', 'uppar', 'waal', 'ney', 'afso', 'hums', 'dur', 'hai', 'wo']
# 0	0.50005150	b'bade fursat se usey banaya hai usey uppar waal ney afso hums dur hai wo'
# THE TWEET IS: @esp__132 oh really :( i saw a few gif posts and some had seen really happy about it, but maybe it's people who'd be happy with any naruhina
# THE PROCESSED TWEET IS: ['oh', 'realli', 'saw', 'gif', 'post', 'seen', 'realli', 'happi', 'mayb', 'peopl', 'whod', 'happi', 'naruhina']
# 0	0.50330927	b'oh realli saw gif post seen realli happi mayb peopl whod happi naruhina'
# THE TWEET IS: @hausofbekah @JudasDiamonds Thats an English nameeee :(( Haiqal isnt an English name but you remember him
# THE PROCESSED TWEET IS: ['that', 'english', 'nameee', 'haiqal', 'isnt', 'english', 'name', 'rememb']
# 0	0.50019101	b'that english nameee haiqal isnt english name rememb'
# THE TWEET IS: @nextofficial my instore card expired in June &amp; I havent been sent a new one :(
# THE PROCESSED TWEET IS: ['instor', 'card', 'expir', 'june', 'amp', 'havent', 'sent', 'new', 'one']
# 0	0.50214866	b'instor card expir june amp havent sent new one'
# THE TWEET IS: @loyalistofSoShi MCountdown pre-voting is begin, we are at 5th place :(
# THE PROCESSED TWEET IS: ['mcountdown', 'prevot', 'begin', '5th', 'place']
# 0	0.50014704	b'mcountdown prevot begin 5th place'
# THE TWEET IS: I felt bad when Irene forgot what she was going to say :(
# THE PROCESSED TWEET IS: ['felt', 'bad', 'iren', 'forgot', 'go', 'say']
# 0	0.50003923	b'felt bad iren forgot go say'
# THE TWEET IS: @flrsbea wow that's great! What's your username? :(
# THE PROCESSED TWEET IS: ['wow', 'that', 'great', 'what', 'usernam']
# 0	0.50170464	b'wow that great what usernam'
# THE TWEET IS: Minho  still injured  ,, :( ,, get well Oppa
# we miss you &lt;3
# THE PROCESSED TWEET IS: ['minho', 'still', 'injur', 'get', 'well', 'oppa', 'miss', 'lt3']
# 0	0.50048435	b'minho still injur get well oppa miss lt3'
# THE TWEET IS: GUYS add me on SNAPCHAT - AmargoLonnard #snapchat #kikmeboys #sexy #french #dirtykik #newmusic #sexcams :( http://t.co/TXdc692SgB
# THE PROCESSED TWEET IS: ['guy', 'add', 'snapchat', 'amargolonnard', 'snapchat', 'kikmeboy', 'sexi', 'french', 'dirtykik', 'newmus', 'sexcam']
# 0	0.50015358	b'guy add snapchat amargolonnard snapchat kikmeboy sexi french dirtykik newmus sexcam'
# THE TWEET IS: @Glassyskyx u change u say i change tsk :(
# THE PROCESSED TWEET IS: ['u', 'chang', 'u', 'say', 'chang', 'tsk']
# 0	0.50114158	b'u chang u say chang tsk'
# THE TWEET IS: Like why did you have to join the marines? :-(
# THE PROCESSED TWEET IS: ['like', 'join', 'marin']
# 0	0.50099132	b'like join marin'
# THE TWEET IS: Hotel for Dogs was pretty sad too where the brother &amp; sister got separated :(
# THE PROCESSED TWEET IS: ['hotel', 'dog', 'pretti', 'sad', 'brother', 'amp', 'sister', 'got', 'separ']
# 0	0.50070416	b'hotel dog pretti sad brother amp sister got separ'
# THE TWEET IS: PAYDAY, but feels like payhour as its all gone to my bills immediately :(
# THE PROCESSED TWEET IS: ['payday', 'feel', 'like', 'payhour', 'gone', 'bill', 'immedi']
# 0	0.50029026	b'payday feel like payhour gone bill immedi'
# THE TWEET IS: @_MeKeLe_ @YogscastLewis Nope :( Best place to get it first is to pre-order on Amazon: http://t.co/fZRCI1xONv
# THE PROCESSED TWEET IS: ['nope', 'best', 'place', 'get', 'first', 'preorder', 'amazon']
# 0	0.50138257	b'nope best place get first preorder amazon'
# THE TWEET IS: @jobhopjulie I was there on the Sunday for a little while.  Not been able to get up much this year, busy :( all looked great tho!
# THE PROCESSED TWEET IS: ['sunday', 'littl', 'abl', 'get', 'much', 'year', 'busi', 'look', 'great', 'tho']
# 0	0.50268602	b'sunday littl abl get much year busi look great tho'
# THE TWEET IS: @Cramdaline It just doesn't go away... you must go to the dentist. :( #poorKid
# THE PROCESSED TWEET IS: ['doesnt', 'go', 'away', 'must', 'go', 'dentist', 'poorkid']
# 0	0.50028174	b'doesnt go away must go dentist poorkid'
# THE TWEET IS: @denocte Thanks - lack of time is a problem, isn't it :(
# THE PROCESSED TWEET IS: ['thank', 'lack', 'time', 'problem', 'isnt']
# 0	0.50471805	b'thank lack time problem isnt'
# THE TWEET IS: When you get misunderstood :(
# THE PROCESSED TWEET IS: ['get', 'misunderstood']
# 0	0.50054936	b'get misunderstood'
# THE TWEET IS: when ur cat is super nice and cuddly but then suddenly scratches and tries to bite :(
#
# like who can i trust anymore
# THE PROCESSED TWEET IS: ['ur', 'cat', 'super', 'nice', 'cuddli', 'suddenli', 'scratch', 'tri', 'bite', 'like', 'trust', 'anymor']
# 0	0.50162943	b'ur cat super nice cuddli suddenli scratch tri bite like trust anymor'
# THE TWEET IS: I hit my thumb :(.
# THE PROCESSED TWEET IS: ['hit', 'thumb']
# 0	0.50010318	b'hit thumb'
# THE TWEET IS: @iloveksoo we almost got to see his cute ankles but his socks :(
# THE PROCESSED TWEET IS: ['almost', 'got', 'see', 'cute', 'ankl', 'sock']
# 0	0.50097933	b'almost got see cute ankl sock'
# THE TWEET IS: @dnwrld that song is not on here :(
# THE PROCESSED TWEET IS: ['song']
# 0	0.50000846	b'song'
# THE TWEET IS: I couldn't sleep last night n it didn't help me waking up at 8 this morning n my phone wasn't even charged :(
# THE PROCESSED TWEET IS: ['couldnt', 'sleep', 'last', 'night', 'n', 'didnt', 'help', 'wake', '8', 'morn', 'n', 'phone', 'wasnt', 'even', 'charg']
# 0	0.50060920	b'couldnt sleep last night n didnt help wake 8 morn n phone wasnt even charg'
# THE TWEET IS: I need to like, tell myself na, na okay lang :((((
# THE PROCESSED TWEET IS: ['need', 'like', 'tell', 'na', 'na', 'okay', 'lang']
# 0	0.50100203	b'need like tell na na okay lang'
# THE TWEET IS: @Laraibmufc follow back :(
# THE PROCESSED TWEET IS: ['follow', 'back']
# 0	0.50188047	b'follow back'
# THE TWEET IS: my heart is currently torturing itself :( lol wat
# THE PROCESSED TWEET IS: ['heart', 'current', 'tortur', 'lol', 'wat']
# 0	0.50022294	b'heart current tortur lol wat'
# THE TWEET IS: @CallmeHaRsh female student killed in some caste love kirkiri :(
# THE PROCESSED TWEET IS: ['femal', 'student', 'kill', 'cast', 'love', 'kirkiri']
# 0	0.50259283	b'femal student kill cast love kirkiri'
# THE TWEET IS: I had a dream of you :( https://t.co/OZdMHNQbSU
# THE PROCESSED TWEET IS: ['dream']
# 0	0.50006778	b'dream'
# THE TWEET IS: @UyyChristopher :( Broken hearted? That's just a phase. Don't worry, you can do it!!
# THE PROCESSED TWEET IS: ['broken', 'heart', 'that', 'phase', 'dont', 'worri']
# 0	0.50001631	b'broken heart that phase dont worri'
# THE TWEET IS: @Coles45Coles
#
# wont be in work today, feel so ill :( i have a tummy bug xx
# THE PROCESSED TWEET IS: ['wont', 'work', 'today', 'feel', 'ill', 'tummi', 'bug', 'xx']
# 0	0.50077404	b'wont work today feel ill tummi bug xx'
# THE TWEET IS: Last day on the beach :-(:-(:-(.... http://t.co/oqo9F7FQs9
# THE PROCESSED TWEET IS: ['last', 'day', 'beach']
# 0	0.50124138	b'last day beach'
# THE TWEET IS: @yezzer Visual Studio 2015? it just got out. switched to it already and broke a lot of code :(
# THE PROCESSED TWEET IS: ['visual', 'studio', '2015', 'got', 'switch', 'alreadi', 'broke', 'lot', 'code']
# 0	0.50070024	b'visual studio 2015 got switch alreadi broke lot code'
# THE TWEET IS: @MTNza seriously this is unfair some are not asking questions! There are ready to answer and win :( ='(  while we busy asking questions!!
# THE PROCESSED TWEET IS: ['serious', 'unfair', 'ask', 'question', 'readi', 'answer', 'win', 'busi', 'ask', 'question']
# 0	0.50055886	b'serious unfair ask question readi answer win busi ask question'
# THE TWEET IS: @ranaPTX_ BUT WHO WILL LEAD US WHEN YOU'RE GONE :((
# THE PROCESSED TWEET IS: ['lead', 'us', 'your', 'gone']
# 0	0.50118593	b'lead us your gone'
# THE TWEET IS: @LiLGeekette but that is the point. Because it is YOLO I sort of die when lactose is in me... Ugh like 3 months pregnant bloating :(
# THE PROCESSED TWEET IS: ['point', 'yolo', 'sort', 'die', 'lactos', 'ugh', 'like', '3', 'month', 'pregnant', 'bloat']
# 0	0.50084739	b'point yolo sort die lactos ugh like 3 month pregnant bloat'
# THE TWEET IS: Im not getting ollys tweet notifications :(
# THE PROCESSED TWEET IS: ['im', 'get', 'olli', 'tweet', 'notif']
# 0	0.50038251	b'im get olli tweet notif'
# THE TWEET IS: going home tomorrow :-(
# THE PROCESSED TWEET IS: ['go', 'home', 'tomorrow']
# 0	0.50014076	b'go home tomorrow'
# THE TWEET IS: @Glanny_ @RohYB_ @_wattie your team killed me :(
# THE PROCESSED TWEET IS: ['team', 'kill']
# 0	0.50012393	b'team kill'
# THE TWEET IS: @MattElyas no way!! :(
# THE PROCESSED TWEET IS: ['way']
# 0	0.50014387	b'way'
# THE TWEET IS: is everyone gonna be talking abt rat boy today bc :((
# THE PROCESSED TWEET IS: ['everyon', 'gonna', 'talk', 'abt', 'rat', 'boy', 'today', 'bc']
# 0	0.50059785	b'everyon gonna talk abt rat boy today bc'
# THE TWEET IS: Why on earth did I assume it wouldn't rain in London? Most likely influenced by overall warm and dry past weeks in continental Europe :(
# THE PROCESSED TWEET IS: ['earth', 'assum', 'wouldnt', 'rain', 'london', 'like', 'influenc', 'overal', 'warm', 'dri', 'past', 'week', 'continent', 'europ']
# 0	0.50152361	b'earth assum wouldnt rain london like influenc overal warm dri past week continent europ'
# THE TWEET IS: @dongvvoo1122 😀🔫 r u sure u want that b r u h we barely survive w them in tank tops :((
# THE PROCESSED TWEET IS: ['😀🔫', 'r', 'u', 'sure', 'u', 'want', 'b', 'r', 'u', 'h', 'bare', 'surviv', 'w', 'tank', 'top']
# 0	0.50157407	b' r u sure u want b r u h bare surviv w tank top'
# THE TWEET IS: @AmericanFujoshi doesn't have the sound effects :(
# THE PROCESSED TWEET IS: ['doesnt', 'sound', 'effect']
# 0	0.50013672	b'doesnt sound effect'
# THE TWEET IS: I Blame Rantie For All Of This :(
# THE PROCESSED TWEET IS: ['blame', 'ranti']
# 0	0.50000399	b'blame ranti'
# THE TWEET IS: @BlatBlatKLANG ummmm ok?  this is a new development :(
# THE PROCESSED TWEET IS: ['ummmm', 'ok', 'new', 'develop']
# 0	0.50099254	b'ummmm ok new develop'
# THE TWEET IS: You guys are never on :( — Aw sorry we're really bust atm.. Shall be back soon http://t.co/YHfZFhLCgr
# THE PROCESSED TWEET IS: ['guy', 'never', '—', 'aw', 'sorri', 'realli', 'bust', 'atm', 'shall', 'back', 'soon']
# 0	0.50002584	b'guy never  aw sorri realli bust atm shall back soon'
# THE TWEET IS: @ddlovato @Vevo bad :( I don't like it. This video is  too many perverse.
# THE PROCESSED TWEET IS: ['bad', 'dont', 'like', 'video', 'mani', 'pervers']
# 0	0.50061237	b'bad dont like video mani pervers'
# THE TWEET IS: first time to go to school without my bracelets :(( it feels odd
# THE PROCESSED TWEET IS: ['first', 'time', 'go', 'school', 'without', 'bracelet', 'feel', 'odd']
# 0	0.50007983	b'first time go school without bracelet feel odd'
# THE TWEET IS: @ayyedolans IM NOT UNTIL THE TWINS FOLLOW ME BACK BYLFNNZ :(
# THE PROCESSED TWEET IS: ['im', 'twin', 'follow', 'back', 'bylfnnz']
# 0	0.50137502	b'im twin follow back bylfnnz'
# THE TWEET IS: @PulkitSamrat @yamigautam that is unfair ..why u should banned our all film in Pakistan :(
# THE PROCESSED TWEET IS: ['unfair', 'u', 'ban', 'film', 'pakistan']
# 0	0.50048009	b'unfair u ban film pakistan'
# THE TWEET IS: Hmmm 10 mins to get my train and I'm currently about 15 mins away :( #failsatlife
# THE PROCESSED TWEET IS: ['hmmm', '10', 'min', 'get', 'train', 'im', 'current', '15', 'min', 'away', 'failsatlif']
# 0	0.50025490	b'hmmm 10 min get train im current 15 min away failsatlif'
# THE TWEET IS: @louanndavies Completely agree. The press won't :(
# THE PROCESSED TWEET IS: ['complet', 'agre', 'press', 'wont']
# 0	0.50004915	b'complet agre press wont'
# THE TWEET IS: Having boring time :( don't know what to do.....
# THE PROCESSED TWEET IS: ['bore', 'time', 'dont', 'know']
# 0	0.50041499	b'bore time dont know'
# THE TWEET IS: ill be on soon, I PROMISE :(
# waaah
# THE PROCESSED TWEET IS: ['ill', 'soon', 'promis', 'waaah']
# 0	0.50067303	b'ill soon promis waaah'
# THE TWEET IS: @eawoman As a Hull supporter I am expecting a misserable few weeks :-(
# THE PROCESSED TWEET IS: ['hull', 'support', 'expect', 'misser', 'week']
# 0	0.50054842	b'hull support expect misser week'

# %% [markdown]
# Later in this specialization, we will see how we can use deeplearning to improve the prediction performance.

# %% [markdown]
# <a name='6'></a>
# ## 6 - Predict with your own Tweet

# %%
# Feel free to change the tweet below
my_tweet = 'This is a fine bright movie. The plot was successfully and I was great until the ending!'
print(process_tweet(my_tweet))
y_hat = predict_tweet(my_tweet, freqs, theta)
print(y_hat)
if y_hat > 0.5:
    print('Positive sentiment')
else:
    print('Negative sentiment')
# Out:
# ['fine', 'bright', 'movi', 'plot', 'success', 'great', 'end']
# [[0.51250149]]
# Positive sentiment
